# %%
import json
import itertools
import copy
import random


def load_lexicon(lexicon_path, train_path):
    lexicon = json.load(open(lexicon_path))
    inputs = []
    with open(train_path, 'r') as f:
        for line in f:
            inputs.append(line.split('\t')[:2])
    return lexicon, inputs

def filter_uncommon_tokens(lexicon, threshold):
    # Filter uncommon tokens
    deleted_keys = set()
    
    for (k1, v1) in lexicon.items():
        deleted_codes = set()
        
        for c, count in v1.items():
            if count < threshold:
                deleted_codes.add(c)
        
        for k in deleted_codes:
            del v1[k]
            
        if len(v1) == 0:
            deleted_keys.add(k1)
            
    for k in deleted_keys:
        del lexicon[k]
        
    return lexicon


def filter_intersected_tokens(lexicon):
    deleted_keys = set()
    for (k1, v1) in lexicon.items():
        for ci, count in v1.items():
            for (k2, v2) in lexicon.items():
                if k2 == k1:
                    continue
                if ci in v2:
                    deleted_keys.add(k1)
                    deleted_keys.add(k2)
    for k in deleted_keys:
        del lexicon[k]
    return lexicon
    

def get_swapables(lexicon, inputs):
    inputs = copy.deepcopy(inputs)
    random.shuffle(inputs)
    swapables = {k: [] for k in lexicon.keys()}
    for k1 in lexicon.keys():
        for k2 in lexicon.keys():
            if k1 != k2:
                if k1 in swapables[k2]:
                    swapables[k1].append(k2)
                else:   
                    x1s = itertools.islice(filter(lambda x: k1 in x, inputs), 5000)
                    x2s = itertools.islice(filter(lambda x: k2 in x, inputs), 5000)
                    for (x1, x2) in itertools.product(x1s, x2s):
                        if ' ' in x1 and ' ' in x2 and x1.replace(k1, k2) == x2:
                            swapables[k1].append(k2)
                            print(f"Linked {k1} - {k2}")
                            break
    deleted_keys = set()               
    for k, v in swapables.items():
        if len(v) == 0:
            deleted_keys.add(k)
            
    for k in deleted_keys:
        del lexicon[k]
        del swapables[k]
             
    return (lexicon, swapables)

def propagate_swaps(swapables):
    
    for k1, swaps in swapables.items():
        for k2 in swaps:
            swaps2 = swapables[k2]
            if k1 in swaps2 and k2 not in swaps:
                swaps.append(k2)
            elif k2 in swaps and k1 not in swaps2:
                swaps2.append(k1)
    
    for k1, swaps in swapables.items():
        for k2 in swaps:
            for k3 in swapables[k2]:
                if k3 != k2 and k3 not in swaps:
                    swaps.append(k3)

    return swapables
    
  
def filter_lexicon_v2(lexicon, inputs):
    lexicon = copy.deepcopy(lexicon)
    lexicon = filter_uncommon_tokens(lexicon, 0) # len(inputs)/100)
    lexicon = filter_intersected_tokens(lexicon)
    lexicon, swapables = get_swapables(lexicon, inputs)
    return lexicon, propagate_swaps(swapables)

# %%
lexicon, inputs = load_lexicon("/raid/lingo/akyurek/git/align/COGS/cogs/alignments/intersect.align.o.json", "/raid/lingo/akyurek/git/align/COGS/cogs/train.tsv")

# %%
filtered_lexicon, swapables = filter_lexicon_v2(lexicon, [input[0] for input in inputs])
# Out:
# Linked rose - dog
# Linked rose - sailor
# Linked rose - boy
# Linked rose - teacher
# Linked rose - girl
# Linked rose - cake
# Linked rose - captain
# Linked rose - cookie
# Linked rose - ring
# Linked rose - horse
# Linked rose - mouse
# Linked rose - strawberry
# Linked rose - cat
# Linked rose - book
# Linked rose - giraffe
# Linked rose - donut
# Linked rose - box
# Linked rose - pencil
# Linked rose - deer
# Linked rose - pen
# Linked rose - butterfly
# Linked rose - melon
# Linked rose - bottle
# Linked rose - priest
# Linked rose - lawyer
# Linked rose - bat
# Linked rose - drink
# Linked rose - child
# Linked rose - penny
# Linked rose - crayon
# Linked rose - frog
# Linked rose - citizen
# Linked rose - sandwich
# Linked rose - turtle
# Linked rose - game
# Linked rose - monkey
# Linked rose - chalk
# Linked rose - present
# Linked rose - baby
# Linked rose - chair
# Linked rose - raisin
# Linked rose - bee
# Linked rose - brain
# Linked rose - monster
# Linked rose - flag
# Linked rose - muffin
# Linked rose - lion
# Linked rose - scientist
# Linked rose - balloon
# Linked rose - cracker
# Linked rose - cup
# Linked rose - sweetcorn
# Linked rose - fig
# Linked rose - jacket
# Linked rose - pancake
# Linked rose - pretzel
# Linked rose - pig
# Linked rose - glue
# Linked rose - ball
# Linked rose - watch
# Linked rose - biscuit
# Linked rose - wolf
# Linked rose - potato
# Linked rose - leaf
# Linked rose - prisoner
# Linked rose - hat
# Linked rose - pumpkin
# Linked rose - shell
# Linked rose - plant
# Linked rose - banana
# Linked rose - nail
# Linked rose - hammer
# Linked rose - tool
# Linked rose - coin
# Linked rose - bowl
# Linked rose - mandarin
# Linked rose - spoon
# Linked rose - customer
# Linked rose - wine
# Linked rose - hamburger
# Linked rose - chicken
# Linked rose - knife
# Linked rose - crown
# Linked rose - doll
# Linked rose - champion
# Linked rose - journalist
# Linked rose - liver
# Linked rose - professor
# Linked rose - jigsaw
# Linked rose - hen
# Linked rose - soap
# Linked rose - flower
# Linked rose - block
# Linked rose - zebra
# Linked rose - bucket
# Linked rose - scarf
# Linked rose - lollipop
# Linked rose - guy
# Linked rose - crocodile
# Linked rose - director
# Linked rose - chemical
# Linked rose - yogurt
# Linked rose - brick
# Linked rose - shirt
# Linked rose - bunny
# Linked rose - student
# Linked rose - duke
# Linked rose - needle
# Linked rose - moose
# Linked rose - princess
# Linked rose - can
# Linked rose - seed
# Linked rose - guitar
# Linked rose - toy
# Linked rose - clock
# Linked rose - pickle
# Linked rose - hero
# Linked rose - mother
# Linked rose - purse
# Linked rose - radio
# Linked rose - fly
# Linked rose - crystal
# Linked rose - bear
# Linked rose - manager
# Linked rose - basket
# Linked rose - plate
# Linked rose - penguin
# Linked rose - patient
# Linked rose - farmer
# Linked rose - pillow
# Linked rose - writer
# Linked rose - father
# Linked rose - mirror
# Linked rose - gumball
# Linked rose - jar
# Linked rose - pony
# Linked rose - fish
# Linked rose - towel
# Linked rose - newspaper
# Linked rose - fruit
# Linked rose - guest
# Linked rose - beer
# Linked rose - shoe
# Linked rose - pizza
# Linked rose - toothbrush
# Linked rose - king
# Linked rose - cloud
# Linked rose - weapon
# Linked rose - creature
# Linked rose - button
# Linked rose - bag
# Linked rose - bean
# Linked rose - molecule
# Linked rose - brush
# Linked rose - bell
# Linked rose - key
# Linked rose - driver
# Linked helped - rolled
# Linked helped - disintegrated
# Linked helped - studied
# Linked helped - stabbed
# Linked helped - crumpled
# Linked helped - liked
# Linked helped - valued
# Linked helped - respected
# Linked helped - nursed
# Linked helped - missed
# Linked helped - painted
# Linked helped - appreciated
# Linked helped - slid
# Linked helped - changed
# Linked helped - inflated
# Linked helped - decomposed
# Linked helped - loved
# Linked helped - poked
# Linked helped - floated
# Linked helped - held
# Linked helped - doubled
# Linked helped - adored
# Linked helped - improved
# Linked helped - shortened
# Linked helped - noticed
# Linked helped - burned
# Linked helped - heard
# Linked helped - snapped
# Linked helped - found
# Linked helped - packed
# Linked helped - discovered
# Linked helped - pierced
# Linked helped - enlarged
# Linked helped - collapsed
# Linked helped - split
# Linked helped - tolerated
# Linked helped - examined
# Linked helped - reddened
# Linked helped - touched
# Linked helped - juggled
# Linked helped - admired
# Linked helped - tossed
# Linked helped - observed
# Linked helped - worshipped
# Linked helped - squeezed
# Linked dog - sailor
# Linked dog - boy
# Linked dog - teacher
# Linked dog - girl
# Linked dog - cake
# Linked dog - captain
# Linked dog - cookie
# Linked dog - ring
# Linked dog - horse
# Linked dog - mouse
# Linked dog - strawberry
# Linked dog - cat
# Linked dog - book
# Linked dog - giraffe
# Linked dog - donut
# Linked dog - box
# Linked dog - pencil
# Linked dog - deer
# Linked dog - pen
# Linked dog - butterfly
# Linked dog - melon
# Linked dog - bottle
# Linked dog - priest
# Linked dog - lawyer
# Linked dog - bat
# Linked dog - squirrel
# Linked dog - drink
# Linked dog - child
# Linked dog - penny
# Linked dog - crayon
# Linked dog - frog
# Linked dog - citizen
# Linked dog - sandwich
# Linked dog - visitor
# Linked dog - turtle
# Linked dog - game
# Linked dog - monkey
# Linked dog - chalk
# Linked dog - present
# Linked dog - baby
# Linked dog - chair
# Linked dog - raisin
# Linked dog - bee
# Linked dog - monster
# Linked dog - coach
# Linked dog - flag
# Linked dog - muffin
# Linked dog - lion
# Linked dog - scientist
# Linked dog - balloon
# Linked dog - donkey
# Linked dog - cracker
# Linked dog - cup
# Linked dog - sweetcorn
# Linked dog - fig
# Linked dog - jacket
# Linked dog - landlord
# Linked dog - pancake
# Linked dog - spokesman
# Linked dog - pretzel
# Linked dog - pig
# Linked dog - glue
# Linked dog - ball
# Linked dog - friend
# Linked dog - watch
# Linked dog - biscuit
# Linked dog - wolf
# Linked dog - potato
# Linked dog - leaf
# Linked dog - prisoner
# Linked dog - bird
# Linked dog - hat
# Linked dog - pumpkin
# Linked dog - plant
# Linked dog - banana
# Linked dog - hammer
# Linked dog - tool
# Linked dog - coin
# Linked dog - bowl
# Linked dog - mandarin
# Linked dog - customer
# Linked dog - politician
# Linked dog - wine
# Linked dog - hamburger
# Linked dog - chicken
# Linked dog - researcher
# Linked dog - crown
# Linked dog - turkey
# Linked dog - doll
# Linked dog - champion
# Linked dog - cow
# Linked dog - journalist
# Linked dog - liver
# Linked dog - professor
# Linked dog - human
# Linked dog - jigsaw
# Linked dog - hen
# Linked dog - soap
# Linked dog - flower
# Linked dog - block
# Linked dog - prince
# Linked dog - doctor
# Linked dog - zebra
# Linked dog - bucket
# Linked dog - scarf
# Linked dog - lollipop
# Linked dog - goose
# Linked dog - guy
# Linked dog - crocodile
# Linked dog - director
# Linked dog - chemical
# Linked dog - yogurt
# Linked dog - dealer
# Linked dog - lamb
# Linked dog - bunny
# Linked dog - student
# Linked dog - duke
# Linked dog - moose
# Linked dog - kitty
# Linked dog - princess
# Linked dog - seed
# Linked dog - guitar
# Linked dog - tourist
# Linked dog - toy
# Linked dog - clock
# Linked dog - pickle
# Linked dog - hero
# Linked dog - resident
# Linked dog - mother
# Linked dog - radio
# Linked dog - fly
# Linked dog - crystal
# Linked dog - bear
# Linked dog - manager
# Linked dog - basket
# Linked dog - servant
# Linked dog - passenger
# Linked dog - plate
# Linked dog - duck
# Linked dog - penguin
# Linked dog - patient
# Linked dog - farmer
# Linked dog - puppy
# Linked dog - queen
# Linked dog - pillow
# Linked dog - writer
# Linked dog - father
# Linked dog - host
# Linked dog - gumball
# Linked dog - jar
# Linked dog - pony
# Linked dog - tiger
# Linked dog - president
# Linked dog - poet
# Linked dog - producer
# Linked dog - chief
# Linked dog - consumer
# Linked dog - fish
# Linked dog - soldier
# Linked dog - towel
# Linked dog - newspaper
# Linked dog - fruit
# Linked dog - guest
# Linked dog - beer
# Linked dog - shoe
# Linked dog - judge
# Linked dog - pizza
# Linked dog - governor
# Linked dog - guard
# Linked dog - king
# Linked dog - cloud
# Linked dog - creature
# Linked dog - kid
# Linked dog - buyer
# Linked dog - molecule
# Linked dog - brush
# Linked dog - tenant
# Linked dog - sheep
# Linked dog - pupil
# Linked dog - key
# Linked dog - driver
# Linked sailor - boy
# Linked sailor - teacher
# Linked sailor - girl
# Linked sailor - cake
# Linked sailor - captain
# Linked sailor - cookie
# Linked sailor - horse
# Linked sailor - mouse
# Linked sailor - cat
# Linked sailor - giraffe
# Linked sailor - donut
# Linked sailor - pencil
# Linked sailor - deer
# Linked sailor - pen
# Linked sailor - butterfly
# Linked sailor - melon
# Linked sailor - bottle
# Linked sailor - priest
# Linked sailor - lawyer
# Linked sailor - squirrel
# Linked sailor - drink
# Linked sailor - child
# Linked sailor - penny
# Linked sailor - frog
# Linked sailor - citizen
# Linked sailor - visitor
# Linked sailor - turtle
# Linked sailor - monkey
# Linked sailor - baby
# Linked sailor - raisin
# Linked sailor - bee
# Linked sailor - monster
# Linked sailor - coach
# Linked sailor - lion
# Linked sailor - scientist
# Linked sailor - donkey
# Linked sailor - landlord
# Linked sailor - pretzel
# Linked sailor - pig
# Linked sailor - glue
# Linked sailor - friend
# Linked sailor - wolf
# Linked sailor - prisoner
# Linked sailor - bird
# Linked sailor - pumpkin
# Linked sailor - bowl
# Linked sailor - customer
# Linked sailor - politician
# Linked sailor - chicken
# Linked sailor - turkey
# Linked sailor - cow
# Linked sailor - journalist
# Linked sailor - professor
# Linked sailor - hen
# Linked sailor - prince
# Linked sailor - doctor
# Linked sailor - zebra
# Linked sailor - goose
# Linked sailor - guy
# Linked sailor - crocodile
# Linked sailor - director
# Linked sailor - chemical
# Linked sailor - dealer
# Linked sailor - lamb
# Linked sailor - bunny
# Linked sailor - student
# Linked sailor - duke
# Linked sailor - needle
# Linked sailor - moose
# Linked sailor - kitty
# Linked sailor - princess
# Linked sailor - tourist
# Linked sailor - resident
# Linked sailor - mother
# Linked sailor - fly
# Linked sailor - bear
# Linked sailor - manager
# Linked sailor - duck
# Linked sailor - penguin
# Linked sailor - patient
# Linked sailor - farmer
# Linked sailor - puppy
# Linked sailor - queen
# Linked sailor - writer
# Linked sailor - father
# Linked sailor - host
# Linked sailor - jar
# Linked sailor - pony
# Linked sailor - tiger
# Linked sailor - president
# Linked sailor - poet
# Linked sailor - producer
# Linked sailor - chief
# Linked sailor - fish
# Linked sailor - soldier
# Linked sailor - guest
# Linked sailor - judge
# Linked sailor - governor
# Linked sailor - guard
# Linked sailor - king
# Linked sailor - creature
# Linked sailor - kid
# Linked sailor - tenant
# Linked sailor - sheep
# Linked sailor - pupil
# Linked sailor - driver
# Linked boy - teacher
# Linked boy - girl
# Linked boy - cake
# Linked boy - captain
# Linked boy - cookie
# Linked boy - ring
# Linked boy - horse
# Linked boy - mouse
# Linked boy - strawberry
# Linked boy - cat
# Linked boy - book
# Linked boy - giraffe
# Linked boy - donut
# Linked boy - box
# Linked boy - pencil
# Linked boy - deer
# Linked boy - pen
# Linked boy - butterfly
# Linked boy - melon
# Linked boy - bottle
# Linked boy - priest
# Linked boy - lawyer
# Linked boy - bat
# Linked boy - squirrel
# Linked boy - drink
# Linked boy - child
# Linked boy - penny
# Linked boy - crayon
# Linked boy - frog
# Linked boy - citizen
# Linked boy - sandwich
# Linked boy - visitor
# Linked boy - turtle
# Linked boy - game
# Linked boy - monkey
# Linked boy - chalk
# Linked boy - present
# Linked boy - baby
# Linked boy - chair
# Linked boy - raisin
# Linked boy - bee
# Linked boy - brain
# Linked boy - monster
# Linked boy - coach
# Linked boy - flag
# Linked boy - muffin
# Linked boy - lion
# Linked boy - scientist
# Linked boy - balloon
# Linked boy - donkey
# Linked boy - cracker
# Linked boy - cup
# Linked boy - sweetcorn
# Linked boy - fig
# Linked boy - jacket
# Linked boy - landlord
# Linked boy - pancake
# Linked boy - spokesman
# Linked boy - pretzel
# Linked boy - pig
# Linked boy - glue
# Linked boy - ball
# Linked boy - friend
# Linked boy - watch
# Linked boy - biscuit
# Linked boy - wolf
# Linked boy - potato
# Linked boy - leaf
# Linked boy - prisoner
# Linked boy - bird
# Linked boy - hat
# Linked boy - pumpkin
# Linked boy - plant
# Linked boy - banana
# Linked boy - tool
# Linked boy - coin
# Linked boy - bowl
# Linked boy - mandarin
# Linked boy - customer
# Linked boy - politician
# Linked boy - wine
# Linked boy - hamburger
# Linked boy - chicken
# Linked boy - researcher
# Linked boy - turkey
# Linked boy - doll
# Linked boy - champion
# Linked boy - cow
# Linked boy - journalist
# Linked boy - liver
# Linked boy - professor
# Linked boy - human
# Linked boy - jigsaw
# Linked boy - hen
# Linked boy - soap
# Linked boy - flower
# Linked boy - block
# Linked boy - prince
# Linked boy - doctor
# Linked boy - zebra
# Linked boy - bucket
# Linked boy - scarf
# Linked boy - lollipop
# Linked boy - goose
# Linked boy - guy
# Linked boy - crocodile
# Linked boy - director
# Linked boy - chemical
# Linked boy - dealer
# Linked boy - lamb
# Linked boy - shirt
# Linked boy - bunny
# Linked boy - student
# Linked boy - duke
# Linked boy - needle
# Linked boy - moose
# Linked boy - kitty
# Linked boy - princess
# Linked boy - seed
# Linked boy - guitar
# Linked boy - tourist
# Linked boy - toy
# Linked boy - clock
# Linked boy - pickle
# Linked boy - hero
# Linked boy - resident
# Linked boy - mother
# Linked boy - purse
# Linked boy - radio
# Linked boy - fly
# Linked boy - crystal
# Linked boy - bear
# Linked boy - manager
# Linked boy - basket
# Linked boy - servant
# Linked boy - passenger
# Linked boy - plate
# Linked boy - duck
# Linked boy - penguin
# Linked boy - patient
# Linked boy - farmer
# Linked boy - puppy
# Linked boy - queen
# Linked boy - pillow
# Linked boy - writer
# Linked boy - father
# Linked boy - host
# Linked boy - gumball
# Linked boy - jar
# Linked boy - pony
# Linked boy - tiger
# Linked boy - president
# Linked boy - poet
# Linked boy - producer
# Linked boy - chief
# Linked boy - consumer
# Linked boy - fish
# Linked boy - soldier
# Linked boy - towel
# Linked boy - fruit
# Linked boy - guest
# Linked boy - beer
# Linked boy - shoe
# Linked boy - judge
# Linked boy - pizza
# Linked boy - governor
# Linked boy - toothbrush
# Linked boy - guard
# Linked boy - king
# Linked boy - cloud
# Linked boy - weapon
# Linked boy - creature
# Linked boy - kid
# Linked boy - buyer
# Linked boy - molecule
# Linked boy - brush
# Linked boy - tenant
# Linked boy - sheep
# Linked boy - pupil
# Linked boy - key
# Linked boy - driver
# Linked Emma - Evelyn
# Linked Emma - Levi
# Linked Emma - Charlotte
# Linked Emma - Amelia
# Linked Emma - Eleanor
# Linked Emma - Benjamin
# Linked Emma - Isabella
# Linked Emma - Scarlett
# Linked Emma - Liam
# Linked Emma - Olivia
# Linked Emma - Oliver
# Linked Emma - Mia
# Linked Emma - Sophia
# Linked Emma - David
# Linked Emma - Camila
# Linked Emma - James
# Linked Emma - Michael
# Linked Emma - Chloe
# Linked Emma - Dylan
# Linked Emma - Ethan
# Linked Emma - Matthew
# Linked Emma - Elizabeth
# Linked Emma - Ella
# Linked Emma - Ava
# Linked Emma - Alexander
# Linked Emma - Aubrey
# Linked Emma - Hazel
# Linked Emma - Noah
# Linked Emma - Harper
# Linked Emma - Asher
# Linked Emma - Natalie
# Linked Emma - Luna
# Linked Emma - Thomas
# Linked Emma - Avery
# Linked Emma - William
# Linked Emma - Addison
# Linked Emma - Aiden
# Linked Emma - Logan
# Linked Emma - Sebastian
# Linked Emma - Lincoln
# Linked Emma - Lucas
# Linked Emma - Wyatt
# Linked Emma - Layla
# Linked Emma - Abigail
# Linked Emma - Leo
# Linked Emma - Jacob
# Linked Emma - Aria
# Linked Emma - Joshua
# Linked Emma - John
# Linked Emma - Savannah
# Linked Emma - Caleb
# Linked Emma - Nathan
# Linked Emma - Luke
# Linked Emma - Henry
# Linked Emma - Jack
# Linked Emma - Ellie
# Linked Emma - Owen
# Linked Emma - Samuel
# Linked Emma - Julian
# Linked Emma - Skylar
# Linked Emma - Gabriel
# Linked Emma - Aurora
# Linked Emma - Madison
# Linked Emma - Mateo
# Linked Emma - Mason
# Linked Emma - Emily
# Linked Emma - Jayden
# Linked Emma - Jackson
# Linked Emma - Sofia
# Linked Emma - Lily
# Linked Emma - Bella
# Linked Emma - Victoria
# Linked Emma - Daniel
# Linked Emma - Mila
# Linked Emma - Elijah
# Linked Emma - Zoe
# Linked Emma - Leah
# Linked Emma - Grace
# Linked Emma - Andrew
# Linked Emma - Joseph
# Linked Emma - Grayson
# Linked Emma - Penelope
# Linked Emma - Isaac
# Linked Emma - Riley
# Linked Emma - Brooklyn
# Linked Emma - Ryan
# Linked Emma - Stella
# Linked Emma - Violet
# Linked Emma - Theodore
# Linked Emma - Lillian
# Linked Emma - Carter
# Linked Emma - Nora
# Linked Emma - Hannah
# Linked Emma - Jaxon
# Linked Emma - Zoey
# Linked Emma - Christopher
# Linked Emma - Audrey
# Linked Emma - Anthony
# Linked Emma - Claire
# Linked rolled - disintegrated
# Linked rolled - studied
# Linked rolled - stabbed
# Linked rolled - crumpled
# Linked rolled - liked
# Linked rolled - valued
# Linked rolled - respected
# Linked rolled - nursed
# Linked rolled - missed
# Linked rolled - painted
# Linked rolled - appreciated
# Linked rolled - slid
# Linked rolled - laughed
# Linked rolled - changed
# Linked rolled - inflated
# Linked rolled - decomposed
# Linked rolled - smiled
# Linked rolled - loved
# Linked rolled - poked
# Linked rolled - floated
# Linked rolled - cried
# Linked rolled - held
# Linked rolled - doubled
# Linked rolled - adored
# Linked rolled - improved
# Linked rolled - shortened
# Linked rolled - noticed
# Linked rolled - burned
# Linked rolled - heard
# Linked rolled - snapped
# Linked rolled - found
# Linked rolled - packed
# Linked rolled - discovered
# Linked rolled - pierced
# Linked rolled - enlarged
# Linked rolled - collapsed
# Linked rolled - snored
# Linked rolled - split
# Linked rolled - tolerated
# Linked rolled - shattered
# Linked rolled - examined
# Linked rolled - reddened
# Linked rolled - touched
# Linked rolled - juggled
# Linked rolled - admired
# Linked rolled - screamed
# Linked rolled - gasped
# Linked rolled - tossed
# Linked rolled - scoffed
# Linked rolled - stuttered
# Linked rolled - observed
# Linked rolled - worshipped
# Linked rolled - frowned
# Linked rolled - snoozed
# Linked rolled - squeezed
# Linked teacher - girl
# Linked teacher - cake
# Linked teacher - captain
# Linked teacher - cookie
# Linked teacher - horse
# Linked teacher - mouse
# Linked teacher - strawberry
# Linked teacher - cat
# Linked teacher - book
# Linked teacher - giraffe
# Linked teacher - donut
# Linked teacher - box
# Linked teacher - pencil
# Linked teacher - deer
# Linked teacher - butterfly
# Linked teacher - melon
# Linked teacher - bottle
# Linked teacher - priest
# Linked teacher - lawyer
# Linked teacher - squirrel
# Linked teacher - drink
# Linked teacher - child
# Linked teacher - penny
# Linked teacher - crayon
# Linked teacher - frog
# Linked teacher - citizen
# Linked teacher - sandwich
# Linked teacher - visitor
# Linked teacher - game
# Linked teacher - monkey
# Linked teacher - chalk
# Linked teacher - present
# Linked teacher - baby
# Linked teacher - raisin
# Linked teacher - bee
# Linked teacher - monster
# Linked teacher - coach
# Linked teacher - flag
# Linked teacher - muffin
# Linked teacher - lion
# Linked teacher - scientist
# Linked teacher - balloon
# Linked teacher - donkey
# Linked teacher - cup
# Linked teacher - sweetcorn
# Linked teacher - fig
# Linked teacher - landlord
# Linked teacher - spokesman
# Linked teacher - pretzel
# Linked teacher - pig
# Linked teacher - ball
# Linked teacher - friend
# Linked teacher - biscuit
# Linked teacher - wolf
# Linked teacher - leaf
# Linked teacher - prisoner
# Linked teacher - bird
# Linked teacher - pumpkin
# Linked teacher - banana
# Linked teacher - hammer
# Linked teacher - tool
# Linked teacher - bowl
# Linked teacher - mandarin
# Linked teacher - customer
# Linked teacher - politician
# Linked teacher - wine
# Linked teacher - hamburger
# Linked teacher - chicken
# Linked teacher - researcher
# Linked teacher - turkey
# Linked teacher - doll
# Linked teacher - champion
# Linked teacher - cow
# Linked teacher - journalist
# Linked teacher - professor
# Linked teacher - jigsaw
# Linked teacher - hen
# Linked teacher - flower
# Linked teacher - block
# Linked teacher - prince
# Linked teacher - doctor
# Linked teacher - zebra
# Linked teacher - bucket
# Linked teacher - scarf
# Linked teacher - lollipop
# Linked teacher - goose
# Linked teacher - guy
# Linked teacher - crocodile
# Linked teacher - director
# Linked teacher - yogurt
# Linked teacher - dealer
# Linked teacher - lamb
# Linked teacher - bunny
# Linked teacher - student
# Linked teacher - duke
# Linked teacher - needle
# Linked teacher - moose
# Linked teacher - kitty
# Linked teacher - princess
# Linked teacher - guitar
# Linked teacher - tourist
# Linked teacher - toy
# Linked teacher - pickle
# Linked teacher - hero
# Linked teacher - resident
# Linked teacher - mother
# Linked teacher - purse
# Linked teacher - radio
# Linked teacher - fly
# Linked teacher - bear
# Linked teacher - manager
# Linked teacher - servant
# Linked teacher - passenger
# Linked teacher - plate
# Linked teacher - duck
# Linked teacher - penguin
# Linked teacher - patient
# Linked teacher - farmer
# Linked teacher - puppy
# Linked teacher - queen
# Linked teacher - writer
# Linked teacher - father
# Linked teacher - host
# Linked teacher - gumball
# Linked teacher - pony
# Linked teacher - tiger
# Linked teacher - president
# Linked teacher - poet
# Linked teacher - producer
# Linked teacher - chief
# Linked teacher - consumer
# Linked teacher - fish
# Linked teacher - soldier
# Linked teacher - newspaper
# Linked teacher - fruit
# Linked teacher - guest
# Linked teacher - beer
# Linked teacher - shoe
# Linked teacher - judge
# Linked teacher - pizza
# Linked teacher - governor
# Linked teacher - guard
# Linked teacher - king
# Linked teacher - creature
# Linked teacher - button
# Linked teacher - kid
# Linked teacher - buyer
# Linked teacher - tenant
# Linked teacher - sheep
# Linked teacher - pupil
# Linked teacher - key
# Linked teacher - driver
# Linked Evelyn - Levi
# Linked Evelyn - Charlotte
# Linked Evelyn - Amelia
# Linked Evelyn - Eleanor
# Linked Evelyn - Benjamin
# Linked Evelyn - Isabella
# Linked Evelyn - Scarlett
# Linked Evelyn - Liam
# Linked Evelyn - Olivia
# Linked Evelyn - Oliver
# Linked Evelyn - Mia
# Linked Evelyn - Sophia
# Linked Evelyn - David
# Linked Evelyn - Camila
# Linked Evelyn - James
# Linked Evelyn - Michael
# Linked Evelyn - Chloe
# Linked Evelyn - Dylan
# Linked Evelyn - Ethan
# Linked Evelyn - Matthew
# Linked Evelyn - Elizabeth
# Linked Evelyn - Ella
# Linked Evelyn - Ava
# Linked Evelyn - Alexander
# Linked Evelyn - Aubrey
# Linked Evelyn - Hazel
# Linked Evelyn - Noah
# Linked Evelyn - Harper
# Linked Evelyn - Asher
# Linked Evelyn - Luna
# Linked Evelyn - Thomas
# Linked Evelyn - Avery
# Linked Evelyn - William
# Linked Evelyn - Addison
# Linked Evelyn - Aiden
# Linked Evelyn - Logan
# Linked Evelyn - Sebastian
# Linked Evelyn - Lucas
# Linked Evelyn - Wyatt
# Linked Evelyn - Abigail
# Linked Evelyn - Leo
# Linked Evelyn - Jacob
# Linked Evelyn - Aria
# Linked Evelyn - Joshua
# Linked Evelyn - John
# Linked Evelyn - Savannah
# Linked Evelyn - Caleb
# Linked Evelyn - Luke
# Linked Evelyn - Henry
# Linked Evelyn - Jack
# Linked Evelyn - Ellie
# Linked Evelyn - Owen
# Linked Evelyn - Samuel
# Linked Evelyn - Julian
# Linked Evelyn - Gabriel
# Linked Evelyn - Aurora
# Linked Evelyn - Madison
# Linked Evelyn - Mateo
# Linked Evelyn - Mason
# Linked Evelyn - Emily
# Linked Evelyn - Jayden
# Linked Evelyn - Jackson
# Linked Evelyn - Sofia
# Linked Evelyn - Lily
# Linked Evelyn - Bella
# Linked Evelyn - Victoria
# Linked Evelyn - Daniel
# Linked Evelyn - Mila
# Linked Evelyn - Elijah
# Linked Evelyn - Zoe
# Linked Evelyn - Leah
# Linked Evelyn - Andrew
# Linked Evelyn - Joseph
# Linked Evelyn - Grayson
# Linked Evelyn - Penelope
# Linked Evelyn - Riley
# Linked Evelyn - Stella
# Linked Evelyn - Violet
# Linked Evelyn - Theodore
# Linked Evelyn - Carter
# Linked Evelyn - Nora
# Linked Evelyn - Hannah
# Linked Evelyn - Zoey
# Linked Evelyn - Audrey
# Linked Evelyn - Claire
# Linked girl - cake
# Linked girl - captain
# Linked girl - cookie
# Linked girl - ring
# Linked girl - horse
# Linked girl - mouse
# Linked girl - strawberry
# Linked girl - cat
# Linked girl - book
# Linked girl - giraffe
# Linked girl - donut
# Linked girl - box
# Linked girl - pencil
# Linked girl - deer
# Linked girl - pen
# Linked girl - butterfly
# Linked girl - melon
# Linked girl - bottle
# Linked girl - priest
# Linked girl - lawyer
# Linked girl - bat
# Linked girl - squirrel
# Linked girl - drink
# Linked girl - child
# Linked girl - penny
# Linked girl - crayon
# Linked girl - frog
# Linked girl - citizen
# Linked girl - sandwich
# Linked girl - visitor
# Linked girl - turtle
# Linked girl - game
# Linked girl - monkey
# Linked girl - chalk
# Linked girl - present
# Linked girl - baby
# Linked girl - chair
# Linked girl - raisin
# Linked girl - bee
# Linked girl - brain
# Linked girl - monster
# Linked girl - coach
# Linked girl - flag
# Linked girl - muffin
# Linked girl - lion
# Linked girl - scientist
# Linked girl - balloon
# Linked girl - donkey
# Linked girl - cracker
# Linked girl - cup
# Linked girl - sweetcorn
# Linked girl - fig
# Linked girl - jacket
# Linked girl - landlord
# Linked girl - pancake
# Linked girl - spokesman
# Linked girl - pretzel
# Linked girl - pig
# Linked girl - glue
# Linked girl - ball
# Linked girl - friend
# Linked girl - watch
# Linked girl - biscuit
# Linked girl - wolf
# Linked girl - potato
# Linked girl - leaf
# Linked girl - prisoner
# Linked girl - bird
# Linked girl - hat
# Linked girl - pumpkin
# Linked girl - banana
# Linked girl - hammer
# Linked girl - tool
# Linked girl - coin
# Linked girl - bowl
# Linked girl - mandarin
# Linked girl - spoon
# Linked girl - customer
# Linked girl - politician
# Linked girl - wine
# Linked girl - hamburger
# Linked girl - chicken
# Linked girl - knife
# Linked girl - researcher
# Linked girl - crown
# Linked girl - turkey
# Linked girl - doll
# Linked girl - champion
# Linked girl - cow
# Linked girl - journalist
# Linked girl - liver
# Linked girl - professor
# Linked girl - human
# Linked girl - jigsaw
# Linked girl - hen
# Linked girl - soap
# Linked girl - flower
# Linked girl - block
# Linked girl - prince
# Linked girl - doctor
# Linked girl - zebra
# Linked girl - bucket
# Linked girl - scarf
# Linked girl - lollipop
# Linked girl - goose
# Linked girl - guy
# Linked girl - crocodile
# Linked girl - director
# Linked girl - chemical
# Linked girl - yogurt
# Linked girl - dealer
# Linked girl - lamb
# Linked girl - shirt
# Linked girl - bunny
# Linked girl - student
# Linked girl - duke
# Linked girl - needle
# Linked girl - moose
# Linked girl - kitty
# Linked girl - princess
# Linked girl - seed
# Linked girl - guitar
# Linked girl - tourist
# Linked girl - toy
# Linked girl - clock
# Linked girl - pickle
# Linked girl - hero
# Linked girl - resident
# Linked girl - mother
# Linked girl - radio
# Linked girl - fly
# Linked girl - crystal
# Linked girl - bear
# Linked girl - manager
# Linked girl - basket
# Linked girl - servant
# Linked girl - passenger
# Linked girl - plate
# Linked girl - duck
# Linked girl - penguin
# Linked girl - patient
# Linked girl - farmer
# Linked girl - puppy
# Linked girl - queen
# Linked girl - pillow
# Linked girl - writer
# Linked girl - father
# Linked girl - mirror
# Linked girl - host
# Linked girl - gumball
# Linked girl - jar
# Linked girl - pony
# Linked girl - tiger
# Linked girl - president
# Linked girl - poet
# Linked girl - producer
# Linked girl - chief
# Linked girl - consumer
# Linked girl - fish
# Linked girl - soldier
# Linked girl - towel
# Linked girl - newspaper
# Linked girl - fruit
# Linked girl - guest
# Linked girl - beer
# Linked girl - shoe
# Linked girl - judge
# Linked girl - pizza
# Linked girl - governor
# Linked girl - guard
# Linked girl - king
# Linked girl - cloud
# Linked girl - weapon
# Linked girl - creature
# Linked girl - button
# Linked girl - kid
# Linked girl - buyer
# Linked girl - molecule
# Linked girl - brush
# Linked girl - tenant
# Linked girl - sheep
# Linked girl - bell
# Linked girl - pupil
# Linked girl - key
# Linked girl - driver
# Linked cake - captain
# Linked cake - cookie
# Linked cake - ring
# Linked cake - horse
# Linked cake - mouse
# Linked cake - strawberry
# Linked cake - cat
# Linked cake - book
# Linked cake - giraffe
# Linked cake - donut
# Linked cake - box
# Linked cake - pencil
# Linked cake - deer
# Linked cake - pen
# Linked cake - butterfly
# Linked cake - melon
# Linked cake - bottle
# Linked cake - priest
# Linked cake - lawyer
# Linked cake - bat
# Linked cake - drink
# Linked cake - child
# Linked cake - penny
# Linked cake - crayon
# Linked cake - frog
# Linked cake - citizen
# Linked cake - sandwich
# Linked cake - visitor
# Linked cake - turtle
# Linked cake - game
# Linked cake - monkey
# Linked cake - chalk
# Linked cake - present
# Linked cake - baby
# Linked cake - chair
# Linked cake - raisin
# Linked cake - bee
# Linked cake - brain
# Linked cake - monster
# Linked cake - coach
# Linked cake - flag
# Linked cake - muffin
# Linked cake - lion
# Linked cake - scientist
# Linked cake - balloon
# Linked cake - donkey
# Linked cake - cracker
# Linked cake - cup
# Linked cake - sweetcorn
# Linked cake - fig
# Linked cake - jacket
# Linked cake - pancake
# Linked cake - spokesman
# Linked cake - pretzel
# Linked cake - pig
# Linked cake - glue
# Linked cake - ball
# Linked cake - friend
# Linked cake - watch
# Linked cake - biscuit
# Linked cake - wolf
# Linked cake - potato
# Linked cake - leaf
# Linked cake - prisoner
# Linked cake - bird
# Linked cake - hat
# Linked cake - pumpkin
# Linked cake - shell
# Linked cake - plant
# Linked cake - banana
# Linked cake - nail
# Linked cake - hammer
# Linked cake - tool
# Linked cake - coin
# Linked cake - bowl
# Linked cake - mandarin
# Linked cake - spoon
# Linked cake - customer
# Linked cake - politician
# Linked cake - wine
# Linked cake - hamburger
# Linked cake - chicken
# Linked cake - knife
# Linked cake - researcher
# Linked cake - crown
# Linked cake - doll
# Linked cake - champion
# Linked cake - cow
# Linked cake - journalist
# Linked cake - liver
# Linked cake - professor
# Linked cake - jigsaw
# Linked cake - hen
# Linked cake - soap
# Linked cake - flower
# Linked cake - block
# Linked cake - prince
# Linked cake - zebra
# Linked cake - bucket
# Linked cake - scarf
# Linked cake - lollipop
# Linked cake - guy
# Linked cake - director
# Linked cake - chemical
# Linked cake - yogurt
# Linked cake - dealer
# Linked cake - brick
# Linked cake - shirt
# Linked cake - bunny
# Linked cake - student
# Linked cake - duke
# Linked cake - needle
# Linked cake - moose
# Linked cake - kitty
# Linked cake - princess
# Linked cake - can
# Linked cake - seed
# Linked cake - guitar
# Linked cake - toy
# Linked cake - clock
# Linked cake - pickle
# Linked cake - hero
# Linked cake - resident
# Linked cake - mother
# Linked cake - purse
# Linked cake - radio
# Linked cake - fly
# Linked cake - crystal
# Linked cake - bear
# Linked cake - manager
# Linked cake - basket
# Linked cake - passenger
# Linked cake - plate
# Linked cake - duck
# Linked cake - penguin
# Linked cake - patient
# Linked cake - farmer
# Linked cake - puppy
# Linked cake - queen
# Linked cake - pillow
# Linked cake - writer
# Linked cake - father
# Linked cake - mirror
# Linked cake - host
# Linked cake - gumball
# Linked cake - jar
# Linked cake - pony
# Linked cake - tiger
# Linked cake - producer
# Linked cake - consumer
# Linked cake - fish
# Linked cake - soldier
# Linked cake - towel
# Linked cake - newspaper
# Linked cake - fruit
# Linked cake - guest
# Linked cake - beer
# Linked cake - shoe
# Linked cake - pizza
# Linked cake - toothbrush
# Linked cake - king
# Linked cake - cloud
# Linked cake - weapon
# Linked cake - creature
# Linked cake - button
# Linked cake - bag
# Linked cake - buyer
# Linked cake - bean
# Linked cake - molecule
# Linked cake - brush
# Linked cake - tenant
# Linked cake - bell
# Linked cake - pupil
# Linked cake - key
# Linked cake - driver
# Linked forwarded - passed
# Linked forwarded - sold
# Linked forwarded - lended
# Linked forwarded - fed
# Linked forwarded - offered
# Linked forwarded - slipped
# Linked forwarded - awarded
# Linked forwarded - posted
# Linked forwarded - handed
# Linked forwarded - rented
# Linked forwarded - mailed
# Linked forwarded - brought
# Linked forwarded - wired
# Linked forwarded - returned
# Linked forwarded - promised
# Linked forwarded - sent
# Linked forwarded - served
# Linked forwarded - loaned
# Linked Levi - Charlotte
# Linked Levi - Amelia
# Linked Levi - Eleanor
# Linked Levi - Benjamin
# Linked Levi - Isabella
# Linked Levi - Scarlett
# Linked Levi - Liam
# Linked Levi - Olivia
# Linked Levi - Oliver
# Linked Levi - Mia
# Linked Levi - Sophia
# Linked Levi - David
# Linked Levi - James
# Linked Levi - Michael
# Linked Levi - Chloe
# Linked Levi - Dylan
# Linked Levi - Matthew
# Linked Levi - Elizabeth
# Linked Levi - Ella
# Linked Levi - Ava
# Linked Levi - Alexander
# Linked Levi - Noah
# Linked Levi - Asher
# Linked Levi - Natalie
# Linked Levi - Thomas
# Linked Levi - William
# Linked Levi - Aiden
# Linked Levi - Logan
# Linked Levi - Sebastian
# Linked Levi - Wyatt
# Linked Levi - Abigail
# Linked Levi - Leo
# Linked Levi - Jacob
# Linked Levi - Aria
# Linked Levi - Joshua
# Linked Levi - John
# Linked Levi - Savannah
# Linked Levi - Caleb
# Linked Levi - Luke
# Linked Levi - Henry
# Linked Levi - Owen
# Linked Levi - Samuel
# Linked Levi - Julian
# Linked Levi - Aurora
# Linked Levi - Madison
# Linked Levi - Mason
# Linked Levi - Emily
# Linked Levi - Jayden
# Linked Levi - Jackson
# Linked Levi - Sofia
# Linked Levi - Lily
# Linked Levi - Victoria
# Linked Levi - Daniel
# Linked Levi - Mila
# Linked Levi - Elijah
# Linked Levi - Zoe
# Linked Levi - Leah
# Linked Levi - Grace
# Linked Levi - Joseph
# Linked Levi - Riley
# Linked Levi - Stella
# Linked Levi - Violet
# Linked Levi - Theodore
# Linked Levi - Carter
# Linked Levi - Hannah
# Linked Levi - Audrey
# Linked Levi - Anthony
# Linked Levi - Claire
# Linked Charlotte - Amelia
# Linked Charlotte - Eleanor
# Linked Charlotte - Benjamin
# Linked Charlotte - Isabella
# Linked Charlotte - Scarlett
# Linked Charlotte - Liam
# Linked Charlotte - Olivia
# Linked Charlotte - Oliver
# Linked Charlotte - Mia
# Linked Charlotte - Sophia
# Linked Charlotte - David
# Linked Charlotte - Camila
# Linked Charlotte - James
# Linked Charlotte - Michael
# Linked Charlotte - Chloe
# Linked Charlotte - Dylan
# Linked Charlotte - Ethan
# Linked Charlotte - Matthew
# Linked Charlotte - Elizabeth
# Linked Charlotte - Ella
# Linked Charlotte - Ava
# Linked Charlotte - Alexander
# Linked Charlotte - Aubrey
# Linked Charlotte - Hazel
# Linked Charlotte - Noah
# Linked Charlotte - Harper
# Linked Charlotte - Asher
# Linked Charlotte - Natalie
# Linked Charlotte - Luna
# Linked Charlotte - Thomas
# Linked Charlotte - Avery
# Linked Charlotte - William
# Linked Charlotte - Addison
# Linked Charlotte - Aiden
# Linked Charlotte - Logan
# Linked Charlotte - Sebastian
# Linked Charlotte - Lincoln
# Linked Charlotte - Lucas
# Linked Charlotte - Wyatt
# Linked Charlotte - Layla
# Linked Charlotte - Abigail
# Linked Charlotte - Leo
# Linked Charlotte - Jacob
# Linked Charlotte - Aria
# Linked Charlotte - Joshua
# Linked Charlotte - John
# Linked Charlotte - Savannah
# Linked Charlotte - Caleb
# Linked Charlotte - Nathan
# Linked Charlotte - Luke
# Linked Charlotte - Henry
# Linked Charlotte - Jack
# Linked Charlotte - Ellie
# Linked Charlotte - Owen
# Linked Charlotte - Samuel
# Linked Charlotte - Julian
# Linked Charlotte - Skylar
# Linked Charlotte - Aurora
# Linked Charlotte - Madison
# Linked Charlotte - Mateo
# Linked Charlotte - Mason
# Linked Charlotte - Emily
# Linked Charlotte - Jayden
# Linked Charlotte - Jackson
# Linked Charlotte - Sofia
# Linked Charlotte - Lily
# Linked Charlotte - Bella
# Linked Charlotte - Victoria
# Linked Charlotte - Daniel
# Linked Charlotte - Mila
# Linked Charlotte - Elijah
# Linked Charlotte - Zoe
# Linked Charlotte - Leah
# Linked Charlotte - Grace
# Linked Charlotte - Andrew
# Linked Charlotte - Joseph
# Linked Charlotte - Grayson
# Linked Charlotte - Penelope
# Linked Charlotte - Isaac
# Linked Charlotte - Riley
# Linked Charlotte - Brooklyn
# Linked Charlotte - Ryan
# Linked Charlotte - Stella
# Linked Charlotte - Violet
# Linked Charlotte - Theodore
# Linked Charlotte - Lillian
# Linked Charlotte - Carter
# Linked Charlotte - Nora
# Linked Charlotte - Hannah
# Linked Charlotte - Jaxon
# Linked Charlotte - Zoey
# Linked Charlotte - Christopher
# Linked Charlotte - Audrey
# Linked Charlotte - Anthony
# Linked Charlotte - Claire
# Linked captain - cookie
# Linked captain - horse
# Linked captain - mouse
# Linked captain - cat
# Linked captain - giraffe
# Linked captain - box
# Linked captain - butterfly
# Linked captain - priest
# Linked captain - drink
# Linked captain - child
# Linked captain - crayon
# Linked captain - frog
# Linked captain - sandwich
# Linked captain - visitor
# Linked captain - monkey
# Linked captain - baby
# Linked captain - raisin
# Linked captain - monster
# Linked captain - coach
# Linked captain - lion
# Linked captain - scientist
# Linked captain - donkey
# Linked captain - landlord
# Linked captain - pancake
# Linked captain - pig
# Linked captain - bird
# Linked captain - customer
# Linked captain - politician
# Linked captain - hamburger
# Linked captain - chicken
# Linked captain - turkey
# Linked captain - cow
# Linked captain - journalist
# Linked captain - professor
# Linked captain - jigsaw
# Linked captain - hen
# Linked captain - block
# Linked captain - prince
# Linked captain - zebra
# Linked captain - goose
# Linked captain - guy
# Linked captain - crocodile
# Linked captain - director
# Linked captain - lamb
# Linked captain - bunny
# Linked captain - duke
# Linked captain - kitty
# Linked captain - princess
# Linked captain - tourist
# Linked captain - toy
# Linked captain - hero
# Linked captain - mother
# Linked captain - purse
# Linked captain - fly
# Linked captain - bear
# Linked captain - manager
# Linked captain - plate
# Linked captain - duck
# Linked captain - penguin
# Linked captain - patient
# Linked captain - puppy
# Linked captain - writer
# Linked captain - father
# Linked captain - tiger
# Linked captain - president
# Linked captain - poet
# Linked captain - producer
# Linked captain - chief
# Linked captain - fish
# Linked captain - soldier
# Linked captain - guest
# Linked captain - judge
# Linked captain - governor
# Linked captain - guard
# Linked captain - weapon
# Linked captain - creature
# Linked captain - buyer
# Linked captain - tenant
# Linked captain - sheep
# Linked captain - driver
# Linked needed - liked
# Linked needed - meant
# Linked needed - hoped
# Linked needed - preferred
# Linked needed - expected
# Linked needed - loved
# Linked needed - dreamed
# Linked needed - wanted
# Linked needed - attempted
# Linked needed - craved
# Linked needed - wished
# Linked needed - hated
# Linked needed - planned
# Linked needed - longed
# Linked needed - intended
# Linked needed - tried
# Linked needed - itched
# Linked needed - enjoyed
# Linked needed - yearned
# Linked cookie - ring
# Linked cookie - horse
# Linked cookie - mouse
# Linked cookie - strawberry
# Linked cookie - cat
# Linked cookie - book
# Linked cookie - giraffe
# Linked cookie - donut
# Linked cookie - box
# Linked cookie - pencil
# Linked cookie - pen
# Linked cookie - butterfly
# Linked cookie - melon
# Linked cookie - bottle
# Linked cookie - priest
# Linked cookie - bat
# Linked cookie - drink
# Linked cookie - child
# Linked cookie - penny
# Linked cookie - crayon
# Linked cookie - frog
# Linked cookie - citizen
# Linked cookie - sandwich
# Linked cookie - visitor
# Linked cookie - turtle
# Linked cookie - game
# Linked cookie - monkey
# Linked cookie - chalk
# Linked cookie - present
# Linked cookie - baby
# Linked cookie - chair
# Linked cookie - raisin
# Linked cookie - bee
# Linked cookie - brain
# Linked cookie - monster
# Linked cookie - flag
# Linked cookie - muffin
# Linked cookie - lion
# Linked cookie - scientist
# Linked cookie - balloon
# Linked cookie - cracker
# Linked cookie - cup
# Linked cookie - sweetcorn
# Linked cookie - fig
# Linked cookie - jacket
# Linked cookie - pancake
# Linked cookie - pretzel
# Linked cookie - pig
# Linked cookie - glue
# Linked cookie - ball
# Linked cookie - friend
# Linked cookie - watch
# Linked cookie - biscuit
# Linked cookie - potato
# Linked cookie - leaf
# Linked cookie - bird
# Linked cookie - hat
# Linked cookie - pumpkin
# Linked cookie - shell
# Linked cookie - plant
# Linked cookie - banana
# Linked cookie - nail
# Linked cookie - hammer
# Linked cookie - tool
# Linked cookie - coin
# Linked cookie - bowl
# Linked cookie - mandarin
# Linked cookie - spoon
# Linked cookie - customer
# Linked cookie - wine
# Linked cookie - hamburger
# Linked cookie - chicken
# Linked cookie - knife
# Linked cookie - researcher
# Linked cookie - crown
# Linked cookie - turkey
# Linked cookie - doll
# Linked cookie - cow
# Linked cookie - journalist
# Linked cookie - liver
# Linked cookie - professor
# Linked cookie - jigsaw
# Linked cookie - soap
# Linked cookie - flower
# Linked cookie - block
# Linked cookie - prince
# Linked cookie - zebra
# Linked cookie - bucket
# Linked cookie - scarf
# Linked cookie - lollipop
# Linked cookie - guy
# Linked cookie - director
# Linked cookie - chemical
# Linked cookie - yogurt
# Linked cookie - brick
# Linked cookie - shirt
# Linked cookie - bunny
# Linked cookie - student
# Linked cookie - duke
# Linked cookie - needle
# Linked cookie - can
# Linked cookie - seed
# Linked cookie - guitar
# Linked cookie - toy
# Linked cookie - clock
# Linked cookie - pickle
# Linked cookie - hero
# Linked cookie - purse
# Linked cookie - radio
# Linked cookie - fly
# Linked cookie - crystal
# Linked cookie - bear
# Linked cookie - basket
# Linked cookie - passenger
# Linked cookie - plate
# Linked cookie - duck
# Linked cookie - penguin
# Linked cookie - patient
# Linked cookie - farmer
# Linked cookie - queen
# Linked cookie - pillow
# Linked cookie - father
# Linked cookie - mirror
# Linked cookie - host
# Linked cookie - gumball
# Linked cookie - jar
# Linked cookie - pony
# Linked cookie - producer
# Linked cookie - chief
# Linked cookie - consumer
# Linked cookie - fish
# Linked cookie - soldier
# Linked cookie - towel
# Linked cookie - newspaper
# Linked cookie - fruit
# Linked cookie - guest
# Linked cookie - beer
# Linked cookie - shoe
# Linked cookie - pizza
# Linked cookie - toothbrush
# Linked cookie - cloud
# Linked cookie - weapon
# Linked cookie - button
# Linked cookie - bag
# Linked cookie - buyer
# Linked cookie - bean
# Linked cookie - molecule
# Linked cookie - brush
# Linked cookie - tenant
# Linked cookie - bell
# Linked cookie - key
# Linked cookie - driver
# Linked passed - sold
# Linked passed - lended
# Linked passed - fed
# Linked passed - offered
# Linked passed - slipped
# Linked passed - awarded
# Linked passed - posted
# Linked passed - handed
# Linked passed - rented
# Linked passed - mailed
# Linked passed - brought
# Linked passed - wired
# Linked passed - returned
# Linked passed - promised
# Linked passed - sent
# Linked passed - served
# Linked passed - loaned
# Linked ring - horse
# Linked ring - strawberry
# Linked ring - cat
# Linked ring - book
# Linked ring - donut
# Linked ring - box
# Linked ring - pencil
# Linked ring - pen
# Linked ring - butterfly
# Linked ring - melon
# Linked ring - bottle
# Linked ring - bat
# Linked ring - drink
# Linked ring - child
# Linked ring - penny
# Linked ring - crayon
# Linked ring - frog
# Linked ring - sandwich
# Linked ring - turtle
# Linked ring - game
# Linked ring - chalk
# Linked ring - present
# Linked ring - baby
# Linked ring - chair
# Linked ring - raisin
# Linked ring - bee
# Linked ring - flag
# Linked ring - muffin
# Linked ring - lion
# Linked ring - balloon
# Linked ring - cracker
# Linked ring - cup
# Linked ring - sweetcorn
# Linked ring - jacket
# Linked ring - pancake
# Linked ring - pretzel
# Linked ring - pig
# Linked ring - glue
# Linked ring - ball
# Linked ring - watch
# Linked ring - biscuit
# Linked ring - potato
# Linked ring - leaf
# Linked ring - bird
# Linked ring - hat
# Linked ring - pumpkin
# Linked ring - plant
# Linked ring - banana
# Linked ring - nail
# Linked ring - hammer
# Linked ring - tool
# Linked ring - coin
# Linked ring - bowl
# Linked ring - mandarin
# Linked ring - spoon
# Linked ring - wine
# Linked ring - hamburger
# Linked ring - knife
# Linked ring - crown
# Linked ring - doll
# Linked ring - liver
# Linked ring - professor
# Linked ring - jigsaw
# Linked ring - soap
# Linked ring - flower
# Linked ring - block
# Linked ring - zebra
# Linked ring - bucket
# Linked ring - scarf
# Linked ring - lollipop
# Linked ring - chemical
# Linked ring - yogurt
# Linked ring - brick
# Linked ring - shirt
# Linked ring - needle
# Linked ring - can
# Linked ring - seed
# Linked ring - guitar
# Linked ring - toy
# Linked ring - clock
# Linked ring - pickle
# Linked ring - radio
# Linked ring - fly
# Linked ring - crystal
# Linked ring - bear
# Linked ring - basket
# Linked ring - plate
# Linked ring - pillow
# Linked ring - father
# Linked ring - mirror
# Linked ring - gumball
# Linked ring - jar
# Linked ring - pony
# Linked ring - towel
# Linked ring - newspaper
# Linked ring - fruit
# Linked ring - beer
# Linked ring - shoe
# Linked ring - pizza
# Linked ring - toothbrush
# Linked ring - cloud
# Linked ring - weapon
# Linked ring - button
# Linked ring - bag
# Linked ring - bean
# Linked ring - molecule
# Linked ring - brush
# Linked ring - bell
# Linked ring - key
# Linked beside - on
# Linked bed - table
# Linked bed - stage
# Linked bed - stool
# Linked horse - mouse
# Linked horse - strawberry
# Linked horse - cat
# Linked horse - book
# Linked horse - giraffe
# Linked horse - donut
# Linked horse - box
# Linked horse - pencil
# Linked horse - deer
# Linked horse - pen
# Linked horse - butterfly
# Linked horse - melon
# Linked horse - bottle
# Linked horse - priest
# Linked horse - lawyer
# Linked horse - bat
# Linked horse - squirrel
# Linked horse - drink
# Linked horse - child
# Linked horse - penny
# Linked horse - crayon
# Linked horse - frog
# Linked horse - citizen
# Linked horse - sandwich
# Linked horse - visitor
# Linked horse - turtle
# Linked horse - game
# Linked horse - monkey
# Linked horse - chalk
# Linked horse - baby
# Linked horse - chair
# Linked horse - raisin
# Linked horse - bee
# Linked horse - monster
# Linked horse - coach
# Linked horse - flag
# Linked horse - lion
# Linked horse - scientist
# Linked horse - balloon
# Linked horse - donkey
# Linked horse - cracker
# Linked horse - cup
# Linked horse - sweetcorn
# Linked horse - jacket
# Linked horse - landlord
# Linked horse - pancake
# Linked horse - spokesman
# Linked horse - pretzel
# Linked horse - pig
# Linked horse - glue
# Linked horse - ball
# Linked horse - watch
# Linked horse - wolf
# Linked horse - potato
# Linked horse - leaf
# Linked horse - prisoner
# Linked horse - bird
# Linked horse - hat
# Linked horse - pumpkin
# Linked horse - bowl
# Linked horse - mandarin
# Linked horse - customer
# Linked horse - wine
# Linked horse - hamburger
# Linked horse - chicken
# Linked horse - researcher
# Linked horse - turkey
# Linked horse - champion
# Linked horse - cow
# Linked horse - professor
# Linked horse - hen
# Linked horse - soap
# Linked horse - flower
# Linked horse - block
# Linked horse - prince
# Linked horse - doctor
# Linked horse - zebra
# Linked horse - bucket
# Linked horse - lollipop
# Linked horse - goose
# Linked horse - guy
# Linked horse - crocodile
# Linked horse - director
# Linked horse - chemical
# Linked horse - lamb
# Linked horse - bunny
# Linked horse - student
# Linked horse - duke
# Linked horse - moose
# Linked horse - kitty
# Linked horse - princess
# Linked horse - seed
# Linked horse - guitar
# Linked horse - tourist
# Linked horse - clock
# Linked horse - pickle
# Linked horse - hero
# Linked horse - mother
# Linked horse - fly
# Linked horse - crystal
# Linked horse - bear
# Linked horse - manager
# Linked horse - basket
# Linked horse - passenger
# Linked horse - plate
# Linked horse - duck
# Linked horse - penguin
# Linked horse - patient
# Linked horse - farmer
# Linked horse - queen
# Linked horse - pillow
# Linked horse - writer
# Linked horse - father
# Linked horse - jar
# Linked horse - pony
# Linked horse - tiger
# Linked horse - president
# Linked horse - poet
# Linked horse - producer
# Linked horse - chief
# Linked horse - consumer
# Linked horse - fish
# Linked horse - soldier
# Linked horse - towel
# Linked horse - fruit
# Linked horse - guest
# Linked horse - beer
# Linked horse - shoe
# Linked horse - judge
# Linked horse - pizza
# Linked horse - governor
# Linked horse - cloud
# Linked horse - creature
# Linked horse - kid
# Linked horse - buyer
# Linked horse - molecule
# Linked horse - brush
# Linked horse - tenant
# Linked horse - sheep
# Linked horse - pupil
# Linked horse - key
# Linked horse - driver
# Linked table - book
# Linked table - box
# Linked table - bottle
# Linked table - stage
# Linked table - house
# Linked table - basket
# Linked table - car
# Linked table - glass
# Linked table - coffin
# Linked table - rock
# Linked mouse - strawberry
# Linked mouse - cat
# Linked mouse - book
# Linked mouse - giraffe
# Linked mouse - donut
# Linked mouse - box
# Linked mouse - pencil
# Linked mouse - deer
# Linked mouse - pen
# Linked mouse - butterfly
# Linked mouse - melon
# Linked mouse - bottle
# Linked mouse - priest
# Linked mouse - lawyer
# Linked mouse - squirrel
# Linked mouse - drink
# Linked mouse - child
# Linked mouse - penny
# Linked mouse - crayon
# Linked mouse - frog
# Linked mouse - citizen
# Linked mouse - sandwich
# Linked mouse - visitor
# Linked mouse - game
# Linked mouse - monkey
# Linked mouse - chalk
# Linked mouse - present
# Linked mouse - baby
# Linked mouse - chair
# Linked mouse - raisin
# Linked mouse - bee
# Linked mouse - monster
# Linked mouse - coach
# Linked mouse - flag
# Linked mouse - muffin
# Linked mouse - lion
# Linked mouse - scientist
# Linked mouse - balloon
# Linked mouse - donkey
# Linked mouse - cup
# Linked mouse - sweetcorn
# Linked mouse - fig
# Linked mouse - landlord
# Linked mouse - pretzel
# Linked mouse - pig
# Linked mouse - glue
# Linked mouse - ball
# Linked mouse - watch
# Linked mouse - biscuit
# Linked mouse - wolf
# Linked mouse - leaf
# Linked mouse - prisoner
# Linked mouse - bird
# Linked mouse - pumpkin
# Linked mouse - banana
# Linked mouse - hammer
# Linked mouse - bowl
# Linked mouse - mandarin
# Linked mouse - customer
# Linked mouse - politician
# Linked mouse - wine
# Linked mouse - hamburger
# Linked mouse - chicken
# Linked mouse - researcher
# Linked mouse - turkey
# Linked mouse - doll
# Linked mouse - champion
# Linked mouse - cow
# Linked mouse - journalist
# Linked mouse - professor
# Linked mouse - jigsaw
# Linked mouse - hen
# Linked mouse - flower
# Linked mouse - block
# Linked mouse - prince
# Linked mouse - doctor
# Linked mouse - zebra
# Linked mouse - bucket
# Linked mouse - scarf
# ...
# Linked passenger - puppy
# Linked passenger - queen
# Linked passenger - pillow
# Linked passenger - consumer
# Linked passenger - fish
# Linked passenger - shoe
# Linked passenger - guard
# Linked passenger - molecule
# Linked passenger - brush
# Linked plate - pillow
# Linked plate - father
# Linked plate - mirror
# Linked plate - gumball
# Linked plate - jar
# Linked plate - pony
# Linked plate - towel
# Linked plate - newspaper
# Linked plate - fruit
# Linked plate - beer
# Linked plate - shoe
# Linked plate - pizza
# Linked plate - toothbrush
# Linked plate - cloud
# Linked plate - weapon
# Linked plate - button
# Linked plate - bag
# Linked plate - bean
# Linked plate - molecule
# Linked plate - brush
# Linked plate - bell
# Linked plate - key
# Linked gasped - scoffed
# Linked gasped - stuttered
# Linked gasped - observed
# Linked gasped - frowned
# Linked gasped - snoozed
# Linked duck - penguin
# Linked duck - patient
# Linked duck - farmer
# Linked duck - puppy
# Linked duck - queen
# Linked duck - pony
# Linked duck - tiger
# Linked duck - producer
# Linked duck - chief
# Linked duck - consumer
# Linked duck - fish
# Linked duck - guest
# Linked duck - shoe
# Linked duck - judge
# Linked duck - governor
# Linked duck - guard
# Linked duck - creature
# Linked duck - button
# Linked duck - kid
# Linked duck - buyer
# Linked duck - tenant
# Linked duck - pupil
# Linked tossed - observed
# Linked tossed - worshipped
# Linked tossed - squeezed
# Linked penguin - patient
# Linked penguin - farmer
# Linked penguin - queen
# Linked penguin - writer
# Linked penguin - father
# Linked penguin - host
# Linked penguin - tiger
# Linked penguin - president
# Linked penguin - producer
# Linked penguin - chief
# Linked penguin - fish
# Linked penguin - soldier
# Linked penguin - fruit
# Linked penguin - guest
# Linked penguin - judge
# Linked penguin - pizza
# Linked penguin - governor
# Linked penguin - king
# Linked penguin - creature
# Linked penguin - tenant
# Linked penguin - driver
# Linked Elijah - Zoe
# Linked Elijah - Grace
# Linked Elijah - Andrew
# Linked Elijah - Joseph
# Linked Elijah - Grayson
# Linked Elijah - Penelope
# Linked Elijah - Isaac
# Linked Elijah - Riley
# Linked Elijah - Brooklyn
# Linked Elijah - Ryan
# Linked Elijah - Stella
# Linked Elijah - Violet
# Linked Elijah - Theodore
# Linked Elijah - Lillian
# Linked Elijah - Carter
# Linked Elijah - Nora
# Linked Elijah - Jaxon
# Linked Elijah - Zoey
# Linked Elijah - Christopher
# Linked Elijah - Audrey
# Linked Elijah - Anthony
# Linked Zoe - Grace
# Linked Zoe - Brooklyn
# Linked Zoe - Stella
# Linked Zoe - Lillian
# Linked Zoe - Carter
# Linked Zoe - Jaxon
# Linked Zoe - Zoey
# Linked Zoe - Anthony
# Linked patient - farmer
# Linked patient - puppy
# Linked patient - writer
# Linked patient - gumball
# Linked patient - pony
# Linked patient - tiger
# Linked patient - poet
# Linked patient - producer
# Linked patient - fish
# Linked patient - guest
# Linked patient - governor
# Linked patient - guard
# Linked patient - weapon
# Linked patient - creature
# Linked patient - sheep
# Linked patient - driver
# Linked Leah - Grace
# Linked Leah - Joseph
# Linked Leah - Grayson
# Linked Leah - Penelope
# Linked Leah - Riley
# Linked Leah - Stella
# Linked Leah - Violet
# Linked Leah - Theodore
# Linked Leah - Lillian
# Linked Leah - Hannah
# Linked Leah - Zoey
# Linked Leah - Christopher
# Linked Leah - Audrey
# Linked Leah - Anthony
# Linked Leah - Claire
# Linked farmer - father
# Linked farmer - pony
# Linked farmer - tiger
# Linked farmer - chief
# Linked farmer - fish
# Linked farmer - soldier
# Linked farmer - newspaper
# Linked farmer - guest
# Linked farmer - pizza
# Linked farmer - guard
# Linked farmer - king
# Linked farmer - creature
# Linked farmer - pupil
# Linked farmer - key
# Linked Grace - Andrew
# Linked Grace - Joseph
# Linked Grace - Isaac
# Linked Grace - Riley
# Linked Grace - Brooklyn
# Linked Grace - Theodore
# Linked Grace - Lillian
# Linked Grace - Zoey
# Linked Grace - Christopher
# Linked Grace - Anthony
# Linked puppy - queen
# Linked puppy - tiger
# Linked puppy - producer
# Linked puppy - consumer
# Linked puppy - king
# Linked puppy - kid
# Linked puppy - pupil
# Linked scoffed - stuttered
# Linked scoffed - observed
# Linked scoffed - frowned
# Linked scoffed - snoozed
# Linked queen - host
# Linked queen - president
# Linked queen - producer
# Linked queen - consumer
# Linked queen - fish
# Linked queen - king
# Linked queen - kid
# Linked queen - buyer
# Linked queen - pupil
# Linked queen - driver
# Linked pillow - mirror
# Linked pillow - gumball
# Linked pillow - jar
# Linked pillow - consumer
# Linked pillow - fish
# Linked pillow - towel
# Linked pillow - newspaper
# Linked pillow - fruit
# Linked pillow - beer
# Linked pillow - shoe
# Linked pillow - pizza
# Linked pillow - toothbrush
# Linked pillow - cloud
# Linked pillow - weapon
# Linked pillow - button
# Linked pillow - bag
# Linked pillow - bean
# Linked pillow - molecule
# Linked pillow - brush
# Linked pillow - bell
# Linked pillow - key
# Linked pillow - driver
# Linked writer - father
# Linked writer - pony
# Linked writer - tiger
# Linked writer - president
# Linked writer - poet
# Linked writer - producer
# Linked writer - chief
# Linked writer - fish
# Linked writer - soldier
# Linked writer - guest
# Linked writer - judge
# Linked writer - governor
# Linked writer - king
# Linked writer - tenant
# Linked writer - sheep
# Linked writer - driver
# Linked father - jar
# Linked father - pony
# Linked father - tiger
# Linked father - president
# Linked father - poet
# Linked father - chief
# Linked father - fish
# Linked father - soldier
# Linked father - towel
# Linked father - newspaper
# Linked father - fruit
# Linked father - guest
# Linked father - beer
# Linked father - shoe
# Linked father - judge
# Linked father - pizza
# Linked father - governor
# Linked father - king
# Linked father - cloud
# Linked father - creature
# Linked father - tenant
# Linked father - sheep
# Linked father - key
# Linked father - driver
# Linked Andrew - Joseph
# Linked Andrew - Grayson
# Linked Andrew - Penelope
# Linked Andrew - Isaac
# Linked Andrew - Riley
# Linked Andrew - Violet
# Linked Andrew - Theodore
# Linked Andrew - Lillian
# Linked Andrew - Nora
# Linked Andrew - Jaxon
# Linked Andrew - Zoey
# Linked Andrew - Christopher
# Linked Andrew - Anthony
# Linked Joseph - Grayson
# Linked Joseph - Isaac
# Linked Joseph - Riley
# Linked Joseph - Brooklyn
# Linked Joseph - Ryan
# Linked Joseph - Stella
# Linked Joseph - Violet
# Linked Joseph - Theodore
# Linked Joseph - Lillian
# Linked Joseph - Nora
# Linked Joseph - Hannah
# Linked Joseph - Jaxon
# Linked Joseph - Zoey
# Linked Joseph - Christopher
# Linked Joseph - Audrey
# Linked Joseph - Anthony
# Linked Joseph - Claire
# Linked mirror - gumball
# Linked mirror - jar
# Linked mirror - towel
# Linked mirror - newspaper
# Linked mirror - fruit
# Linked mirror - beer
# Linked mirror - shoe
# Linked mirror - pizza
# Linked mirror - toothbrush
# Linked mirror - cloud
# Linked mirror - weapon
# Linked mirror - button
# Linked mirror - bag
# Linked mirror - bean
# Linked mirror - brush
# Linked mirror - bell
# Linked mirror - key
# Linked host - pony
# Linked host - tiger
# Linked host - president
# Linked host - chief
# Linked host - soldier
# Linked host - governor
# Linked host - king
# Linked host - creature
# Linked host - kid
# Linked host - buyer
# Linked host - sheep
# Linked host - pupil
# Linked tried - itched
# Linked tried - enjoyed
# Linked tried - yearned
# Linked gumball - jar
# Linked gumball - towel
# Linked gumball - newspaper
# Linked gumball - fruit
# Linked gumball - beer
# Linked gumball - shoe
# Linked gumball - pizza
# Linked gumball - toothbrush
# Linked gumball - cloud
# Linked gumball - weapon
# Linked gumball - button
# Linked gumball - bag
# Linked gumball - bean
# Linked gumball - molecule
# Linked gumball - brush
# Linked gumball - bell
# Linked gumball - key
# Linked jar - pony
# Linked jar - towel
# Linked jar - newspaper
# Linked jar - fruit
# Linked jar - beer
# Linked jar - shoe
# Linked jar - pizza
# Linked jar - toothbrush
# Linked jar - cloud
# Linked jar - weapon
# Linked jar - bag
# Linked jar - bean
# Linked jar - molecule
# Linked jar - brush
# Linked jar - bell
# Linked jar - key
# Linked pony - tiger
# Linked pony - president
# Linked pony - poet
# Linked pony - chief
# Linked pony - fish
# Linked pony - soldier
# Linked pony - towel
# Linked pony - newspaper
# Linked pony - fruit
# Linked pony - guest
# Linked pony - beer
# Linked pony - shoe
# Linked pony - judge
# Linked pony - pizza
# Linked pony - governor
# Linked pony - king
# Linked pony - cloud
# Linked pony - creature
# Linked pony - kid
# Linked pony - tenant
# Linked pony - sheep
# Linked pony - key
# Linked pony - driver
# Linked tiger - president
# Linked tiger - poet
# Linked tiger - producer
# Linked tiger - chief
# Linked tiger - fish
# Linked tiger - soldier
# Linked tiger - guest
# Linked tiger - judge
# Linked tiger - governor
# Linked tiger - guard
# Linked tiger - king
# Linked tiger - creature
# Linked tiger - tenant
# Linked tiger - sheep
# Linked tiger - pupil
# Linked tiger - driver
# Linked president - chief
# Linked president - soldier
# Linked president - guest
# Linked president - judge
# Linked president - king
# Linked president - kid
# Linked president - buyer
# Linked president - tenant
# Linked poet - chief
# Linked poet - fish
# Linked poet - soldier
# Linked poet - guest
# Linked poet - governor
# Linked poet - guard
# Linked poet - king
# Linked poet - creature
# Linked poet - tenant
# Linked poet - sheep
# Linked poet - driver
# Linked producer - king
# Linked producer - pupil
# Linked chief - fish
# Linked chief - soldier
# Linked chief - guest
# Linked chief - judge
# Linked chief - governor
# Linked chief - king
# Linked chief - creature
# Linked chief - tenant
# Linked chief - sheep
# Linked chief - pupil
# Linked chief - driver
# Linked consumer - fish
# Linked consumer - shoe
# Linked consumer - molecule
# Linked consumer - brush
# Linked fish - soldier
# Linked fish - newspaper
# Linked fish - guest
# Linked fish - shoe
# Linked fish - pizza
# Linked fish - governor
# Linked fish - guard
# Linked fish - king
# Linked fish - creature
# Linked fish - buyer
# Linked fish - molecule
# Linked fish - brush
# Linked fish - tenant
# Linked fish - sheep
# Linked fish - key
# Linked fish - driver
# Linked Grayson - Isaac
# Linked Grayson - Ryan
# Linked Grayson - Theodore
# Linked Grayson - Lillian
# Linked Grayson - Carter
# Linked Grayson - Nora
# Linked Grayson - Hannah
# Linked Grayson - Jaxon
# Linked Grayson - Anthony
# Linked Grayson - Claire
# Linked Penelope - Riley
# Linked Penelope - Stella
# Linked Penelope - Hannah
# Linked Penelope - Zoey
# Linked Penelope - Christopher
# Linked itched - enjoyed
# Linked soldier - newspaper
# Linked soldier - guest
# Linked soldier - beer
# Linked soldier - shoe
# Linked soldier - judge
# Linked soldier - governor
# Linked soldier - king
# Linked soldier - creature
# Linked soldier - buyer
# Linked soldier - tenant
# Linked soldier - sheep
# Linked soldier - pupil
# Linked soldier - driver
# Linked enjoyed - yearned
# Linked towel - newspaper
# Linked towel - fruit
# Linked towel - beer
# Linked towel - shoe
# Linked towel - pizza
# Linked towel - toothbrush
# Linked towel - cloud
# Linked towel - weapon
# Linked towel - button
# Linked towel - bag
# Linked towel - bean
# Linked towel - brush
# Linked towel - bell
# Linked towel - key
# Linked newspaper - fruit
# Linked newspaper - guest
# Linked newspaper - beer
# Linked newspaper - shoe
# Linked newspaper - pizza
# Linked newspaper - toothbrush
# Linked newspaper - king
# Linked newspaper - cloud
# Linked newspaper - weapon
# Linked newspaper - creature
# Linked newspaper - bag
# Linked newspaper - buyer
# Linked newspaper - bean
# Linked newspaper - molecule
# Linked newspaper - brush
# Linked newspaper - bell
# Linked newspaper - key
# Linked Isaac - Riley
# Linked Isaac - Stella
# Linked Isaac - Theodore
# Linked Isaac - Lillian
# Linked Isaac - Carter
# Linked Isaac - Hannah
# Linked Isaac - Zoey
# Linked Isaac - Christopher
# Linked Isaac - Audrey
# Linked Isaac - Anthony
# Linked fruit - beer
# Linked fruit - shoe
# Linked fruit - pizza
# Linked fruit - toothbrush
# Linked fruit - cloud
# Linked fruit - weapon
# Linked fruit - button
# Linked fruit - bag
# Linked fruit - bean
# Linked fruit - molecule
# Linked fruit - brush
# Linked fruit - bell
# Linked fruit - key
# Linked Riley - Brooklyn
# Linked Riley - Ryan
# Linked Riley - Violet
# Linked Riley - Theodore
# Linked Riley - Lillian
# Linked Riley - Carter
# Linked Riley - Zoey
# Linked Riley - Christopher
# Linked Riley - Audrey
# Linked Riley - Anthony
# Linked Riley - Claire
# Linked guest - shoe
# Linked guest - judge
# Linked guest - pizza
# Linked guest - governor
# Linked guest - king
# Linked guest - weapon
# Linked guest - creature
# Linked guest - kid
# Linked guest - tenant
# Linked guest - sheep
# Linked guest - key
# Linked guest - driver
# Linked beer - shoe
# Linked beer - pizza
# Linked beer - toothbrush
# Linked beer - cloud
# Linked beer - weapon
# Linked beer - button
# Linked beer - bag
# Linked beer - buyer
# Linked beer - bean
# Linked beer - brush
# Linked beer - bell
# Linked beer - key
# Linked stuttered - observed
# Linked stuttered - frowned
# Linked stuttered - snoozed
# Linked observed - worshipped
# Linked observed - frowned
# Linked observed - snoozed
# Linked Brooklyn - Stella
# Linked Brooklyn - Violet
# Linked Brooklyn - Theodore
# Linked Brooklyn - Lillian
# Linked Brooklyn - Carter
# Linked Brooklyn - Nora
# Linked Brooklyn - Jaxon
# Linked Brooklyn - Christopher
# Linked Brooklyn - Anthony
# Linked shoe - pizza
# Linked shoe - toothbrush
# Linked shoe - cloud
# Linked shoe - weapon
# Linked shoe - button
# Linked shoe - bag
# Linked shoe - buyer
# Linked shoe - bean
# Linked shoe - molecule
# Linked shoe - brush
# Linked shoe - tenant
# Linked shoe - bell
# Linked shoe - key
# Linked judge - kid
# Linked judge - tenant
# Linked judge - pupil
# Linked judge - driver
# Linked Ryan - Audrey
# Linked pizza - toothbrush
# Linked pizza - king
# Linked pizza - cloud
# Linked pizza - weapon
# Linked pizza - creature
# Linked pizza - button
# Linked pizza - bag
# Linked pizza - bean
# Linked pizza - brush
# Linked pizza - bell
# Linked pizza - pupil
# Linked pizza - key
# Linked governor - guard
# Linked governor - king
# Linked governor - creature
# Linked governor - buyer
# Linked governor - tenant
# Linked governor - sheep
# Linked governor - driver
# Linked bun - envelope
# Linked Stella - Violet
# Linked Stella - Theodore
# Linked Stella - Hannah
# Linked Stella - Jaxon
# Linked Stella - Zoey
# Linked Stella - Christopher
# Linked Stella - Audrey
# Linked Stella - Anthony
# Linked Stella - Claire
# Linked toothbrush - cloud
# Linked toothbrush - weapon
# Linked toothbrush - button
# Linked toothbrush - bag
# Linked toothbrush - bean
# Linked toothbrush - brush
# Linked toothbrush - bell
# Linked toothbrush - key
# Linked Violet - Theodore
# Linked Violet - Hannah
# Linked Violet - Zoey
# Linked Violet - Christopher
# Linked Violet - Audrey
# Linked Violet - Anthony
# Linked Violet - Claire
# Linked guard - creature
# Linked guard - buyer
# Linked guard - sheep
# Linked guard - driver
# Linked king - creature
# Linked king - kid
# Linked king - buyer
# Linked king - tenant
# Linked king - sheep
# Linked king - pupil
# Linked king - key
# Linked king - driver
# Linked cloud - weapon
# Linked cloud - button
# Linked cloud - bag
# Linked cloud - bean
# Linked cloud - molecule
# Linked cloud - brush
# Linked cloud - bell
# Linked cloud - key
# Linked weapon - button
# Linked weapon - bag
# Linked weapon - bean
# Linked weapon - molecule
# Linked weapon - brush
# Linked weapon - bell
# Linked weapon - key
# Linked creature - buyer
# Linked creature - pupil
# Linked creature - key
# Linked button - bean
# Linked button - brush
# Linked button - bell
# Linked worshipped - squeezed
# Linked Theodore - Lillian
# Linked Theodore - Carter
# Linked Theodore - Nora
# Linked Theodore - Hannah
# Linked Theodore - Jaxon
# Linked Theodore - Zoey
# Linked Theodore - Christopher
# Linked Theodore - Audrey
# Linked Theodore - Anthony
# Linked Theodore - Claire
# Linked Lillian - Nora
# Linked Lillian - Jaxon
# Linked Lillian - Zoey
# Linked Lillian - Christopher
# Linked Lillian - Anthony
# Linked Carter - Christopher
# Linked Carter - Audrey
# Linked Carter - Anthony
# Linked Nora - Jaxon
# Linked Nora - Audrey
# Linked bag - brush
# Linked kid - buyer
# Linked kid - tenant
# Linked Hannah - Jaxon
# Linked Hannah - Zoey
# Linked Hannah - Audrey
# Linked Hannah - Claire
# Linked buyer - sheep
# Linked bean - molecule
# Linked bean - brush
# Linked bean - bell
# Linked bean - key
# Linked molecule - brush
# Linked Jaxon - Anthony
# Linked Zoey - Christopher
# Linked Zoey - Anthony
# Linked Zoey - Claire
# Linked brush - bell
# Linked brush - key
# Linked tenant - sheep
# Linked tenant - driver
# Linked sheep - driver
# Linked bell - pupil
# Linked Christopher - Audrey
# Linked Christopher - Anthony
# Linked Audrey - Anthony
# Linked Audrey - Claire
# Linked frowned - snoozed

# %%
swapables['baked']
# Out:
# ['packed',
#  'helped',
#  'rolled',
#  'disintegrated',
#  'studied',
#  'stabbed',
#  'crumpled',
#  'liked',
#  'valued',
#  'respected',
#  'nursed',
#  'missed',
#  'painted',
#  'appreciated',
#  'slid',
#  'laughed',
#  'changed',
#  'inflated',
#  'decomposed',
#  'smiled',
#  'loved',
#  'poked',
#  'floated',
#  'cried',
#  'held',
#  'doubled',
#  'adored',
#  'improved',
#  'shortened',
#  'noticed',
#  'burned',
#  'heard',
#  'snapped',
#  'found',
#  'discovered',
#  'pierced',
#  'enlarged',
#  'collapsed',
#  'snored',
#  'split',
#  'tolerated',
#  'examined',
#  'reddened',
#  'touched',
#  'juggled',
#  'admired',
#  'screamed',
#  'gasped',
#  'tossed',
#  'scoffed',
#  'stuttered',
#  'observed',
#  'worshipped',
#  'frowned',
#  'snoozed',
#  'baked',
#  'squeezed',
#  'shattered',
#  'needed',
#  'meant',
#  'hoped',
#  'preferred',
#  'expected',
#  'dreamed',
#  'wanted',
#  'attempted',
#  'craved',
#  'wished',
#  'hated',
#  'planned',
#  'longed',
#  'intended',
#  'confessed',
#  'tried',
#  'itched',
#  'enjoyed',
#  'yearned',
#  'said']

# %%
with open("/raid/lingo/akyurek/git/align/COGS/cogs/alignments/lexicon_and_swapables_v2.json","w") as f:
    json.dump({'lexicon': filtered_lexicon, 'swapables': swapables}, f)

# %%
json.load(open("/raid/lingo/akyurek/git/align/COGS/cogs/alignments/lexicon_and_swapables.json"))
# Out:
# {'lexicon': {'rose': {'rose': 648},
#   'helped': {'help': 509},
#   'dog': {'dog': 871},
#   'sailor': {'sailor': 108},
#   'boy': {'boy': 2029},
#   'Emma': {'Emma': 4151},
#   'rolled': {'roll': 1307},
#   'teacher': {'teacher': 424},
#   'Evelyn': {'Evelyn': 112},
#   'girl': {'girl': 4625},
#   'cake': {'cake': 4847},
#   'forwarded': {'forward': 182},
#   'Levi': {'Levi': 35},
#   'Charlotte': {'Charlotte': 244},
#   'captain': {'captain': 40},
#   'needed': {'need': 115},
#   'cookie': {'cookie': 1225},
#   'passed': {'pass': 336},
#   'ring': {'ring': 54},
#   'beside': {'beside': 1801},
#   'bed': {'bed': 266},
#   'horse': {'horse': 186},
#   'table': {'table': 1143},
#   'mouse': {'mouse': 250},
#   'Amelia': {'Amelia': 145},
#   'strawberry': {'strawberry': 298},
#   'cat': {'cat': 1139},
#   'disintegrated': {'disintegrate': 122},
#   'Eleanor': {'Eleanor': 37},
#   'sold': {'sell': 693},
#   'book': {'book': 242},
#   'lended': {'lend': 1155},
#   'Benjamin': {'Benjamin': 201},
#   'giraffe': {'giraffe': 182},
#   'donut': {'donut': 2074},
#   'studied': {'study': 85},
#   'Isabella': {'Isabella': 371},
#   'box': {'box': 1013},
#   'on': {'on': 1753},
#   'stabbed': {'stab': 66},
#   'Scarlett': {'Scarlett': 55},
#   'pencil': {'pencil': 78},
#   'fed': {'feed': 419},
#   'Liam': {'Liam': 1758},
#   'deer': {'deer': 58},
#   'Olivia': {'Olivia': 1097},
#   'pen': {'pen': 95},
#   'offered': {'offer': 517},
#   'Oliver': {'Oliver': 230},
#   'crumpled': {'crumple': 147},
#   'butterfly': {'butterfly': 111},
#   'melon': {'melon': 368},
#   'bottle': {'bottle': 96},
#   'priest': {'priest': 44},
#   'slipped': {'slip': 166},
#   'awarded': {'award': 231},
#   'liked': {'like': 1849},
#   'lawyer': {'lawyer': 104},
#   'bat': {'bat': 200},
#   'squirrel': {'squirrel': 46},
#   'valued': {'value': 136},
#   'seat': {'seat': 47},
#   'drink': {'drink': 501},
#   'child': {'child': 508},
#   'stage': {'stage': 460},
#   'Mia': {'Mia': 173},
#   'respected': {'respect': 155},
#   'penny': {'penny': 50},
#   'crayon': {'crayon': 138},
#   'nursed': {'nurse': 161},
#   'frog': {'frog': 355},
#   'meant': {'mean': 66},
#   'Sophia': {'Sophia': 278},
#   'citizen': {'citizen': 44},
#   'sandwich': {'sandwich': 323},
#   'missed': {'miss': 116},
#   'hoped': {'hope': 329},
#   'preferred': {'prefer': 174},
#   'visitor': {'visitor': 49},
#   'posted': {'post': 174},
#   'turtle': {'turtle': 42},
#   'painted': {'paint': 541},
#   'David': {'David': 54},
#   'expected': {'expect': 95},
#   'Camila': {'Camila': 65},
#   'house': {'house': 615},
#   'computer': {'computer': 42},
#   'James': {'James': 295},
#   'appreciated': {'appreciate': 167},
#   'slid': {'slide': 191},
#   'laughed': {'laugh': 70},
#   'game': {'game': 142},
#   'changed': {'change': 129},
#   'monkey': {'monkey': 187},
#   'chalk': {'chalk': 157},
#   'present': {'present': 68},
#   'baby': {'baby': 618},
#   'Michael': {'Michael': 88},
#   'chair': {'chair': 224},
#   'Chloe': {'Chloe': 44},
#   'handed': {'hand': 201},
#   'raisin': {'raisin': 410},
#   'rented': {'rent': 248},
#   'bee': {'bee': 86},
#   'sack': {'sack': 7},
#   'brain': {'brain': 44},
#   'inflated': {'inflate': 87},
#   'monster': {'monster': 111},
#   'coach': {'coach': 40},
#   'Dylan': {'Dylan': 33},
#   'flag': {'flag': 48},
#   'Ethan': {'Ethan': 100},
#   'garden': {'garden': 98},
#   'Matthew': {'Matthew': 70},
#   'muffin': {'muffin': 99},
#   'Elizabeth': {'Elizabeth': 104},
#   'Ella': {'Ella': 72},
#   'decomposed': {'decompose': 116},
#   'Ava': {'Ava': 574},
#   'lion': {'lion': 220},
#   'smiled': {'smile': 100},
#   'loved': {'love': 275},
#   'dreamed': {'dream': 83},
#   'storage': {'storage': 23},
#   'scientist': {'scientist': 89},
#   'balloon': {'balloon': 225},
#   'donkey': {'donkey': 64},
#   'cracker': {'cracker': 69},
#   'poked': {'poke': 192},
#   'cup': {'cup': 122},
#   'Alexander': {'Alexander': 92},
#   'sweetcorn': {'sweetcorn': 87},
#   'Aubrey': {'Aubrey': 36},
#   'floated': {'float': 248},
#   'fig': {'fig': 44},
#   'Hazel': {'Hazel': 41},
#   'cried': {'cry': 48},
#   'jacket': {'jacket': 64},
#   'held': {'hold': 89},
#   'landlord': {'landlord': 34},
#   'pancake': {'pancake': 93},
#   'Noah': {'Noah': 752},
#   'spokesman': {'spokesman': 30},
#   'pretzel': {'pretzel': 99},
#   'doubled': {'double': 116},
#   'pig': {'pig': 62},
#   'adored': {'adore': 145},
#   'glue': {'glue': 124},
#   'mailed': {'mail': 166},
#   'ball': {'ball': 272},
#   'Harper': {'Harper': 141},
#   'brought': {'bring': 205},
#   'improved': {'improve': 103},
#   'friend': {'friend': 42},
#   'watch': {'watch': 54},
#   'Asher': {'Asher': 37},
#   'shortened': {'shorten': 321},
#   'Natalie': {'Natalie': 37},
#   'biscuit': {'biscuit': 113},
#   'wanted': {'want': 330},
#   'wolf': {'wolf': 53},
#   'wired': {'wire': 145},
#   'noticed': {'notice': 253},
#   'Luna': {'Luna': 62},
#   'potato': {'potato': 87},
#   'Thomas': {'Thomas': 29},
#   'leaf': {'leaf': 35},
#   'Avery': {'Avery': 68},
#   'burned': {'burn': 408},
#   'prisoner': {'prisoner': 40},
#   'bird': {'bird': 122},
#   'stool': {'stool': 66},
#   'hat': {'hat': 55},
#   'said': {'say': 195},
#   'heard': {'hear': 114},
#   'snapped': {'snap': 112},
#   'pumpkin': {'pumpkin': 78},
#   'William': {'William': 520},
#   'returned': {'return': 187},
#   'shell': {'shell': 37},
#   'plant': {'plant': 40},
#   'Addison': {'Addison': 31},
#   'banana': {'banana': 102},
#   'Aiden': {'Aiden': 53},
#   'Logan': {'Logan': 114},
#   'found': {'find': 318},
#   'nail': {'nail': 28},
#   'packed': {'pack': 105},
#   'hammer': {'hammer': 54},
#   'promised': {'promise': 165},
#   'Sebastian': {'Sebastian': 65},
#   'tool': {'tool': 51},
#   'Lincoln': {'Lincoln': 29},
#   'Lucas': {'Lucas': 132},
#   'Wyatt': {'Wyatt': 47},
#   'coin': {'coin': 44},
#   'bowl': {'bowl': 59},
#   'discovered': {'discover': 76},
#   'mandarin': {'mandarin': 61},
#   'spoon': {'spoon': 58},
#   'customer': {'customer': 84},
#   'politician': {'politician': 34},
#   'room': {'room': 225},
#   'Layla': {'Layla': 53},
#   'wine': {'wine': 39},
#   'Abigail': {'Abigail': 101},
#   'sent': {'send': 297},
#   'Leo': {'Leo': 27},
#   'Jacob': {'Jacob': 91},
#   'hamburger': {'hamburger': 114},
#   'pierced': {'pierce': 71},
#   'chicken': {'chicken': 279},
#   'enlarged': {'enlarge': 104},
#   'knife': {'knife': 55},
#   'researcher': {'researcher': 30},
#   'Aria': {'Aria': 67},
#   'crown': {'crown': 52},
#   'turkey': {'turkey': 49},
#   'Joshua': {'Joshua': 44},
#   'doll': {'doll': 142},
#   'champion': {'champion': 31},
#   'collapsed': {'collapse': 121},
#   'cow': {'cow': 77},
#   'John': {'John': 45},
#   'journalist': {'journalist': 34},
#   'liver': {'liver': 41},
#   'Savannah': {'Savannah': 31},
#   'Caleb': {'Caleb': 32},
#   'professor': {'professor': 100},
#   'human': {'human': 33},
#   'jigsaw': {'jigsaw': 75},
#   'snored': {'snore': 25},
#   'hen': {'hen': 60},
#   'Nathan': {'Nathan': 24},
#   'soap': {'soap': 52},
#   'Luke': {'Luke': 44},
#   'flower': {'flower': 65},
#   'served': {'serve': 244},
#   'block': {'block': 190},
#   'attempted': {'attempt': 55},
#   'Henry': {'Henry': 76},
#   'Jack': {'Jack': 48},
#   'split': {'split': 136},
#   'prince': {'prince': 43},
#   'craved': {'crave': 34},
#   'Ellie': {'Ellie': 43},
#   'doctor': {'doctor': 53},
#   'Owen': {'Owen': 51},
#   'zebra': {'zebra': 61},
#   'tolerated': {'tolerate': 149},
#   'Samuel': {'Samuel': 51},
#   'bucket': {'bucket': 76},
#   'scarf': {'scarf': 55},
#   'lollipop': {'lollipop': 117},
#   'wished': {'wish': 92},
#   'Julian': {'Julian': 31},
#   'shattered': {'shatter': 1},
#   'examined': {'examine': 100},
#   'goose': {'goose': 73},
#   'Skylar': {'Skylar': 39},
#   'reddened': {'redden': 99},
#   'guy': {'guy': 45},
#   'crocodile': {'crocodile': 82},
#   'director': {'director': 53},
#   'hated': {'hate': 33},
#   'planned': {'plan': 71},
#   'touched': {'touch': 81},
#   'chemical': {'chemical': 38},
#   'yogurt': {'yogurt': 83},
#   'juggled': {'juggle': 135},
#   'Gabriel': {'Gabriel': 40},
#   'dealer': {'dealer': 36},
#   'Aurora': {'Aurora': 30},
#   'brick': {'brick': 50},
#   'lamb': {'lamb': 46},
#   'shirt': {'shirt': 44},
#   'bunny': {'bunny': 118},
#   'Madison': {'Madison': 58},
#   'longed': {'long': 28},
#   'student': {'student': 92},
#   'duke': {'duke': 39},
#   'Mateo': {'Mateo': 40},
#   'speaker': {'speaker': 49},
#   'needle': {'needle': 46},
#   'moose': {'moose': 65},
#   'kitty': {'kitty': 54},
#   'Mason': {'Mason': 126},
#   'princess': {'princess': 83},
#   'can': {'can': 67},
#   'admired': {'admire': 213},
#   'seed': {'seed': 44},
#   'guitar': {'guitar': 53},
#   'tourist': {'tourist': 38},
#   'Emily': {'Emily': 104},
#   'toy': {'toy': 62},
#   'clock': {'clock': 57},
#   'Jayden': {'Jayden': 32},
#   'pickle': {'pickle': 88},
#   'Jackson': {'Jackson': 70},
#   'hero': {'hero': 95},
#   'resident': {'resident': 41},
#   'Sofia': {'Sofia': 67},
#   'loaned': {'loan': 159},
#   'mother': {'mother': 41},
#   'Lily': {'Lily': 42},
#   'purse': {'purse': 43},
#   'Bella': {'Bella': 34},
#   'radio': {'radio': 63},
#   'Victoria': {'Victoria': 56},
#   'intended': {'intend': 84},
#   'confessed': {'confess': 105},
#   'fly': {'fly': 67},
#   'crystal': {'crystal': 41},
#   'Daniel': {'Daniel': 78},
#   'screamed': {'scream': 26},
#   'Mila': {'Mila': 90},
#   'bear': {'bear': 208},
#   'manager': {'manager': 63},
#   'basket': {'basket': 69},
#   'servant': {'servant': 31},
#   'passenger': {'passenger': 35},
#   'plate': {'plate': 63},
#   'gasped': {'gasp': 18},
#   'duck': {'duck': 137},
#   'tossed': {'toss': 68},
#   'penguin': {'penguin': 93},
#   'car': {'car': 138},
#   'Elijah': {'Elijah': 163},
#   'Zoe': {'Zoe': 32},
#   'patient': {'patient': 55},
#   'Leah': {'Leah': 33},
#   'farmer': {'farmer': 34},
#   'Grace': {'Grace': 49},
#   'puppy': {'puppy': 50},
#   'scoffed': {'scoff': 22},
#   'queen': {'queen': 56},
#   'pillow': {'pillow': 70},
#   'writer': {'writer': 46},
#   'father': {'father': 49},
#   'Andrew': {'Andrew': 37},
#   'Joseph': {'Joseph': 37},
#   'mirror': {'mirror': 51},
#   'host': {'host': 44},
#   'tried': {'try': 77},
#   'gumball': {'gumball': 64},
#   'jar': {'jar': 50},
#   'pony': {'pony': 50},
#   'tiger': {'tiger': 75},
#   'president': {'president': 68},
#   'poet': {'poet': 48},
#   'producer': {'producer': 39},
#   'chief': {'chief': 34},
#   'consumer': {'consumer': 48},
#   'fish': {'fish': 61},
#   'Grayson': {'Grayson': 44},
#   'Penelope': {'Penelope': 45},
#   'itched': {'itch': 22},
#   'soldier': {'soldier': 42},
#   'enjoyed': {'enjoy': 35},
#   'towel': {'towel': 61},
#   'newspaper': {'newspaper': 57},
#   'Isaac': {'Isaac': 37},
#   'fruit': {'fruit': 48},
#   'Riley': {'Riley': 52},
#   'guest': {'guest': 42},
#   'beer': {'beer': 53},
#   'stuttered': {'stutter': 28},
#   'observed': {'observe': 90},
#   'Brooklyn': {'Brooklyn': 41},
#   'shoe': {'shoe': 96},
#   'judge': {'judge': 32},
#   'Ryan': {'Ryan': 38},
#   'pizza': {'pizza': 80},
#   'governor': {'governor': 32},
#   'bun': {'bun': 7},
#   'Stella': {'Stella': 38},
#   'toothbrush': {'toothbrush': 50},
#   'Violet': {'Violet': 32},
#   'guard': {'guard': 27},
#   'king': {'king': 49},
#   'cloud': {'cloud': 63},
#   'weapon': {'weapon': 54},
#   'creature': {'creature': 42},
#   'button': {'button': 32},
#   'worshipped': {'worship': 77},
#   'Theodore': {'Theodore': 41},
#   'Lillian': {'Lillian': 39},
#   'Carter': {'Carter': 49},
#   'glass': {'glass': 64},
#   'Nora': {'Nora': 43},
#   'bag': {'bag': 89},
#   'kid': {'kid': 50},
#   'Hannah': {'Hannah': 36},
#   'buyer': {'buyer': 43},
#   'bean': {'bean': 34},
#   'envelope': {'envelope': 15},
#   'molecule': {'molecule': 45},
#   'Jaxon': {'Jaxon': 50},
#   'Zoey': {'Zoey': 47},
#   'brush': {'brush': 71},
#   'tenant': {'tenant': 32},
#   'sheep': {'sheep': 47},
#   'bell': {'bell': 51},
#   'Christopher': {'Christopher': 44},
#   'pupil': {'pupil': 44},
#   'key': {'key': 58},
#   'coffin': {'coffin': 16},
#   'Audrey': {'Audrey': 32},
#   'frowned': {'frown': 17},
#   'rock': {'rock': 39},
#   'snoozed': {'snooze': 15},
#   'yearned': {'yearn': 26},
#   'driver': {'driver': 42},
#   'Anthony': {'Anthony': 40},
#   'Paula': {'Paula': 1},
#   'couch': {'couch': 3},
#   'Claire': {'Claire': 29},
#   'baked': {'bake': 1},
#   'shark': {'shark': 1},
#   'squeezed': {'squeeze': 1}},
#  'swapables': {'rose': ['dog',
#    'sailor',
#    'boy',
#    'Emma',
#    'teacher',
#    'girl',
#    'cake',
#    'Charlotte',
#    'captain',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'Scarlett',
#    'pencil',
#    'Liam',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'bat',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'Chloe',
#    'raisin',
#    'bee',
#    'brain',
#    'monster',
#    'flag',
#    'muffin',
#    'Ava',
#    'lion',
#    'scientist',
#    'balloon',
#    'cracker',
#    'cup',
#    'Alexander',
#    'sweetcorn',
#    'fig',
#    'Hazel',
#    'jacket',
#    'pancake',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'watch',
#    'Natalie',
#    'biscuit',
#    'wolf',
#    'potato',
#    'leaf',
#    'prisoner',
#    'bird',
#    'hat',
#    'pumpkin',
#    'shell',
#    'plant',
#    'banana',
#    'nail',
#    'hammer',
#    'Sebastian',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'customer',
#    'Layla',
#    'wine',
#    'hamburger',
#    'chicken',
#    'knife',
#    'crown',
#    'doll',
#    'champion',
#    'journalist',
#    'liver',
#    'professor',
#    'human',
#    'jigsaw',
#    'hen',
#    'soap',
#    'flower',
#    'block',
#    'split',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'guy',
#    'crocodile',
#    'director',
#    'chemical',
#    'yogurt',
#    'brick',
#    'shirt',
#    'bunny',
#    'Madison',
#    'student',
#    'duke',
#    'Mateo',
#    'needle',
#    'moose',
#    'princess',
#    'can',
#    'seed',
#    'guitar',
#    'Emily',
#    'toy',
#    'clock',
#    'pickle',
#    'hero',
#    'mother',
#    'purse',
#    'radio',
#    'fly',
#    'crystal',
#    'Mila',
#    'bear',
#    'manager',
#    'basket',
#    'plate',
#    'penguin',
#    'Zoe',
#    'patient',
#    'farmer',
#    'queen',
#    'pillow',
#    'writer',
#    'father',
#    'mirror',
#    'gumball',
#    'jar',
#    'pony',
#    'tiger',
#    'poet',
#    'fish',
#    'towel',
#    'newspaper',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'pizza',
#    'governor',
#    'toothbrush',
#    'Violet',
#    'king',
#    'cloud',
#    'weapon',
#    'creature',
#    'button',
#    'Carter',
#    'bag',
#    'bean',
#    'molecule',
#    'Jaxon',
#    'Zoey',
#    'brush',
#    'bell',
#    'key',
#    'driver',
#    'Paula',
#    'shark'],
#   'helped': ['rolled',
#    'disintegrated',
#    'studied',
#    'stabbed',
#    'crumpled',
#    'liked',
#    'valued',
#    'respected',
#    'nursed',
#    'missed',
#    'painted',
#    'appreciated',
#    'slid',
#    'changed',
#    'inflated',
#    'decomposed',
#    'loved',
#    'poked',
#    'floated',
#    'held',
#    'doubled',
#    'adored',
#    'improved',
#    'shortened',
#    'noticed',
#    'burned',
#    'heard',
#    'snapped',
#    'found',
#    'packed',
#    'discovered',
#    'pierced',
#    'enlarged',
#    'collapsed',
#    'split',
#    'tolerated',
#    'examined',
#    'reddened',
#    'touched',
#    'juggled',
#    'admired',
#    'tossed',
#    'observed',
#    'worshipped',
#    'squeezed'],
#   'dog': ['rose',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'captain',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'bat',
#    'squirrel',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'monster',
#    'coach',
#    'flag',
#    'muffin',
#    'lion',
#    'scientist',
#    'balloon',
#    'donkey',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'fig',
#    'jacket',
#    'landlord',
#    'pancake',
#    'spokesman',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'friend',
#    'watch',
#    'biscuit',
#    'wolf',
#    'potato',
#    'leaf',
#    'prisoner',
#    'bird',
#    'hat',
#    'pumpkin',
#    'plant',
#    'banana',
#    'hammer',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'customer',
#    'politician',
#    'wine',
#    'hamburger',
#    'chicken',
#    'researcher',
#    'crown',
#    'turkey',
#    'doll',
#    'champion',
#    'cow',
#    'journalist',
#    'liver',
#    'professor',
#    'human',
#    'jigsaw',
#    'hen',
#    'soap',
#    'flower',
#    'block',
#    'prince',
#    'doctor',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'chemical',
#    'yogurt',
#    'dealer',
#    'lamb',
#    'bunny',
#    'student',
#    'duke',
#    'moose',
#    'kitty',
#    'princess',
#    'seed',
#    'guitar',
#    'tourist',
#    'toy',
#    'clock',
#    'pickle',
#    'hero',
#    'resident',
#    'mother',
#    'radio',
#    'fly',
#    'crystal',
#    'bear',
#    'manager',
#    'basket',
#    'servant',
#    'passenger',
#    'plate',
#    'duck',
#    'penguin',
#    'patient',
#    'farmer',
#    'puppy',
#    'queen',
#    'pillow',
#    'writer',
#    'father',
#    'host',
#    'gumball',
#    'jar',
#    'pony',
#    'tiger',
#    'president',
#    'poet',
#    'producer',
#    'chief',
#    'consumer',
#    'fish',
#    'soldier',
#    'towel',
#    'newspaper',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'judge',
#    'pizza',
#    'governor',
#    'guard',
#    'king',
#    'cloud',
#    'creature',
#    'kid',
#    'buyer',
#    'molecule',
#    'brush',
#    'tenant',
#    'sheep',
#    'pupil',
#    'key',
#    'driver'],
#   'sailor': ['rose',
#    'dog',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'captain',
#    'cookie',
#    'horse',
#    'mouse',
#    'cat',
#    'giraffe',
#    'donut',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'squirrel',
#    'drink',
#    'child',
#    'penny',
#    'frog',
#    'citizen',
#    'visitor',
#    'turtle',
#    'monkey',
#    'baby',
#    'raisin',
#    'bee',
#    'monster',
#    'coach',
#    'lion',
#    'scientist',
#    'donkey',
#    'landlord',
#    'pretzel',
#    'pig',
#    'glue',
#    'friend',
#    'wolf',
#    'prisoner',
#    'bird',
#    'pumpkin',
#    'bowl',
#    'customer',
#    'politician',
#    'chicken',
#    'turkey',
#    'cow',
#    'journalist',
#    'professor',
#    'hen',
#    'prince',
#    'doctor',
#    'zebra',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'chemical',
#    'dealer',
#    'lamb',
#    'bunny',
#    'student',
#    'duke',
#    'needle',
#    'moose',
#    'kitty',
#    'princess',
#    'tourist',
#    'resident',
#    'mother',
#    'fly',
#    'bear',
#    'manager',
#    'duck',
#    'penguin',
#    'patient',
#    'farmer',
#    'puppy',
#    'queen',
#    'writer',
#    'father',
#    'host',
#    'jar',
#    'pony',
#    'tiger',
#    'president',
#    'poet',
#    'producer',
#    'chief',
#    'fish',
#    'soldier',
#    'guest',
#    'judge',
#    'governor',
#    'guard',
#    'king',
#    'creature',
#    'kid',
#    'tenant',
#    'sheep',
#    'pupil',
#    'driver'],
#   'boy': ['rose',
#    'dog',
#    'sailor',
#    'teacher',
#    'girl',
#    'cake',
#    'captain',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'bat',
#    'squirrel',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'brain',
#    'monster',
#    'coach',
#    'flag',
#    'muffin',
#    'lion',
#    'scientist',
#    'balloon',
#    'donkey',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'fig',
#    'jacket',
#    'landlord',
#    'pancake',
#    'spokesman',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'friend',
#    'watch',
#    'biscuit',
#    'wolf',
#    'potato',
#    'leaf',
#    'prisoner',
#    'bird',
#    'hat',
#    'pumpkin',
#    'plant',
#    'banana',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'customer',
#    'politician',
#    'wine',
#    'hamburger',
#    'chicken',
#    'researcher',
#    'turkey',
#    'doll',
#    'champion',
#    'cow',
#    'journalist',
#    'liver',
#    'professor',
#    'human',
#    'jigsaw',
#    'hen',
#    'soap',
#    'flower',
#    'block',
#    'prince',
#    'doctor',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'chemical',
#    'dealer',
#    'lamb',
#    'shirt',
#    'bunny',
#    'student',
#    'duke',
#    'needle',
#    'moose',
#    'kitty',
#    'princess',
#    'seed',
#    'guitar',
#    'tourist',
#    'toy',
#    'clock',
#    'pickle',
#    'hero',
#    'resident',
#    'mother',
#    'purse',
#    'radio',
#    'fly',
#    'crystal',
#    'bear',
#    'manager',
#    'basket',
#    'servant',
#    'passenger',
#    'plate',
#    'duck',
#    'penguin',
#    'patient',
#    'farmer',
#    'puppy',
#    'queen',
#    'pillow',
#    'writer',
#    'father',
#    'host',
#    'gumball',
#    'jar',
#    'pony',
#    'tiger',
#    'president',
#    'poet',
#    'producer',
#    'chief',
#    'consumer',
#    'fish',
#    'soldier',
#    'towel',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'judge',
#    'pizza',
#    'governor',
#    'toothbrush',
#    'guard',
#    'king',
#    'cloud',
#    'weapon',
#    'creature',
#    'kid',
#    'buyer',
#    'molecule',
#    'brush',
#    'tenant',
#    'sheep',
#    'pupil',
#    'key',
#    'driver'],
#   'Emma': ['rose',
#    'teacher',
#    'Evelyn',
#    'girl',
#    'Levi',
#    'Charlotte',
#    'cookie',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'box',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'pen',
#    'Oliver',
#    'bottle',
#    'priest',
#    'lawyer',
#    'Mia',
#    'Sophia',
#    'David',
#    'Camila',
#    'James',
#    'game',
#    'chalk',
#    'Michael',
#    'chair',
#    'Chloe',
#    'bee',
#    'brain',
#    'Dylan',
#    'flag',
#    'Ethan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'scientist',
#    'Alexander',
#    'Aubrey',
#    'Hazel',
#    'Noah',
#    'ball',
#    'Harper',
#    'Asher',
#    'Natalie',
#    'Luna',
#    'Thomas',
#    'Avery',
#    'prisoner',
#    'bird',
#    'William',
#    'plant',
#    'Addison',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Lincoln',
#    'Lucas',
#    'Wyatt',
#    'bowl',
#    'spoon',
#    'Layla',
#    'Abigail',
#    'Leo',
#    'Jacob',
#    'knife',
#    'Aria',
#    'Joshua',
#    'John',
#    'liver',
#    'Savannah',
#    'Caleb',
#    'professor',
#    'human',
#    'Nathan',
#    'Luke',
#    'flower',
#    'Henry',
#    'Jack',
#    'split',
#    'Ellie',
#    'Owen',
#    'Samuel',
#    'bucket',
#    'Julian',
#    'Skylar',
#    'director',
#    'Gabriel',
#    'Aurora',
#    'brick',
#    'Madison',
#    'student',
#    'Mateo',
#    'moose',
#    'Mason',
#    'Emily',
#    'clock',
#    'Jayden',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Bella',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Zoe',
#    'Leah',
#    'Grace',
#    'queen',
#    'Andrew',
#    'Joseph',
#    'gumball',
#    'tiger',
#    'poet',
#    'Grayson',
#    'Penelope',
#    'Isaac',
#    'Riley',
#    'Brooklyn',
#    'Ryan',
#    'governor',
#    'Stella',
#    'toothbrush',
#    'Violet',
#    'button',
#    'Theodore',
#    'Lillian',
#    'Carter',
#    'Nora',
#    'Hannah',
#    'Jaxon',
#    'Zoey',
#    'Christopher',
#    'Audrey',
#    'Anthony',
#    'Paula',
#    'Claire',
#    'shark'],
#   'rolled': ['helped',
#    'disintegrated',
#    'studied',
#    'stabbed',
#    'crumpled',
#    'liked',
#    'valued',
#    'respected',
#    'nursed',
#    'missed',
#    'painted',
#    'appreciated',
#    'slid',
#    'laughed',
#    'changed',
#    'inflated',
#    'decomposed',
#    'smiled',
#    'loved',
#    'poked',
#    'floated',
#    'cried',
#    'held',
#    'doubled',
#    'adored',
#    'improved',
#    'shortened',
#    'noticed',
#    'burned',
#    'heard',
#    'snapped',
#    'found',
#    'packed',
#    'discovered',
#    'pierced',
#    'enlarged',
#    'collapsed',
#    'snored',
#    'split',
#    'tolerated',
#    'shattered',
#    'examined',
#    'reddened',
#    'touched',
#    'juggled',
#    'admired',
#    'screamed',
#    'gasped',
#    'tossed',
#    'scoffed',
#    'stuttered',
#    'observed',
#    'worshipped',
#    'frowned',
#    'snoozed',
#    'squeezed'],
#   'teacher': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'Emma',
#    'girl',
#    'cake',
#    'Charlotte',
#    'captain',
#    'cookie',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'Scarlett',
#    'pencil',
#    'Liam',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'squirrel',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'Chloe',
#    'raisin',
#    'bee',
#    'brain',
#    'monster',
#    'coach',
#    'flag',
#    'muffin',
#    'Ava',
#    'lion',
#    'scientist',
#    'balloon',
#    'donkey',
#    'cup',
#    'Alexander',
#    'sweetcorn',
#    'fig',
#    'Hazel',
#    'landlord',
#    'spokesman',
#    'pretzel',
#    'pig',
#    'ball',
#    'friend',
#    'Natalie',
#    'biscuit',
#    'wolf',
#    'leaf',
#    'prisoner',
#    'bird',
#    'pumpkin',
#    'plant',
#    'banana',
#    'hammer',
#    'Sebastian',
#    'tool',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'customer',
#    'politician',
#    'Layla',
#    'wine',
#    'hamburger',
#    'chicken',
#    'knife',
#    'researcher',
#    'turkey',
#    'doll',
#    'champion',
#    'cow',
#    'journalist',
#    'liver',
#    'professor',
#    'human',
#    'jigsaw',
#    'hen',
#    'flower',
#    'block',
#    'split',
#    'prince',
#    'doctor',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'yogurt',
#    'dealer',
#    'brick',
#    'lamb',
#    'bunny',
#    'Madison',
#    'student',
#    'duke',
#    'Mateo',
#    'needle',
#    'moose',
#    'kitty',
#    'princess',
#    'guitar',
#    'tourist',
#    'Emily',
#    'toy',
#    'clock',
#    'pickle',
#    'hero',
#    'resident',
#    'mother',
#    'purse',
#    'radio',
#    'fly',
#    'Mila',
#    'bear',
#    'manager',
#    'servant',
#    'passenger',
#    'plate',
#    'duck',
#    'penguin',
#    'Zoe',
#    'patient',
#    'farmer',
#    'puppy',
#    'queen',
#    'writer',
#    'father',
#    'host',
#    'gumball',
#    'pony',
#    'tiger',
#    'president',
#    'poet',
#    'producer',
#    'chief',
#    'consumer',
#    'fish',
#    'soldier',
#    'newspaper',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'judge',
#    'pizza',
#    'governor',
#    'toothbrush',
#    'Violet',
#    'guard',
#    'king',
#    'creature',
#    'button',
#    'Carter',
#    'kid',
#    'buyer',
#    'Jaxon',
#    'Zoey',
#    'tenant',
#    'sheep',
#    'pupil',
#    'key',
#    'driver',
#    'Paula',
#    'shark'],
#   'Evelyn': ['Emma',
#    'Levi',
#    'Charlotte',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'Oliver',
#    'Mia',
#    'Sophia',
#    'David',
#    'Camila',
#    'James',
#    'Michael',
#    'Chloe',
#    'Dylan',
#    'Ethan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'Alexander',
#    'Aubrey',
#    'Hazel',
#    'Noah',
#    'Harper',
#    'Asher',
#    'Luna',
#    'Thomas',
#    'Avery',
#    'William',
#    'Addison',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Lucas',
#    'Wyatt',
#    'Abigail',
#    'Leo',
#    'Jacob',
#    'Aria',
#    'Joshua',
#    'John',
#    'Savannah',
#    'Caleb',
#    'Luke',
#    'Henry',
#    'Jack',
#    'Ellie',
#    'Owen',
#    'Samuel',
#    'Julian',
#    'Gabriel',
#    'Aurora',
#    'Madison',
#    'Mateo',
#    'Mason',
#    'Emily',
#    'Jayden',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Bella',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Zoe',
#    'Leah',
#    'Andrew',
#    'Joseph',
#    'Grayson',
#    'Penelope',
#    'Riley',
#    'Stella',
#    'Violet',
#    'Theodore',
#    'Carter',
#    'Nora',
#    'Hannah',
#    'Zoey',
#    'Audrey',
#    'Claire'],
#   'girl': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'Emma',
#    'teacher',
#    'cake',
#    'Charlotte',
#    'captain',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'Scarlett',
#    'pencil',
#    'Liam',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'bat',
#    'squirrel',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'Chloe',
#    'raisin',
#    'bee',
#    'brain',
#    'monster',
#    'coach',
#    'flag',
#    'muffin',
#    'Ava',
#    'lion',
#    'scientist',
#    'balloon',
#    'donkey',
#    'cracker',
#    'cup',
#    'Alexander',
#    'sweetcorn',
#    'fig',
#    'Hazel',
#    'jacket',
#    'landlord',
#    'pancake',
#    'spokesman',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'friend',
#    'watch',
#    'Natalie',
#    'biscuit',
#    'wolf',
#    'potato',
#    'leaf',
#    'prisoner',
#    'bird',
#    'hat',
#    'pumpkin',
#    'plant',
#    'banana',
#    'hammer',
#    'Sebastian',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'customer',
#    'politician',
#    'Layla',
#    'wine',
#    'hamburger',
#    'chicken',
#    'knife',
#    'researcher',
#    'crown',
#    'turkey',
#    'doll',
#    'champion',
#    'cow',
#    'journalist',
#    'liver',
#    'professor',
#    'human',
#    'jigsaw',
#    'hen',
#    'soap',
#    'flower',
#    'block',
#    'split',
#    'prince',
#    'doctor',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'chemical',
#    'yogurt',
#    'dealer',
#    'brick',
#    'lamb',
#    'shirt',
#    'bunny',
#    'Madison',
#    'student',
#    'duke',
#    'Mateo',
#    'needle',
#    'moose',
#    'kitty',
#    'princess',
#    'seed',
#    'guitar',
#    'tourist',
#    'Emily',
#    'toy',
#    'clock',
#    'pickle',
#    'hero',
#    'resident',
#    'mother',
#    'radio',
#    'fly',
#    'crystal',
#    'Mila',
#    'bear',
#    'manager',
#    'basket',
#    'servant',
#    'passenger',
#    'plate',
#    'duck',
#    'penguin',
#    'Zoe',
#    'patient',
#    'farmer',
#    'puppy',
#    'queen',
#    'pillow',
#    'writer',
#    'father',
#    'mirror',
#    'host',
#    'gumball',
#    'jar',
#    'pony',
#    'tiger',
#    'president',
#    'poet',
#    'producer',
#    'chief',
#    'consumer',
#    'fish',
#    'soldier',
#    'towel',
#    'newspaper',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'judge',
#    'pizza',
#    'governor',
#    'toothbrush',
#    'Violet',
#    'guard',
#    'king',
#    'cloud',
#    'weapon',
#    'creature',
#    'button',
#    'Carter',
#    'kid',
#    'buyer',
#    'molecule',
#    'Jaxon',
#    'Zoey',
#    'brush',
#    'tenant',
#    'sheep',
#    'bell',
#    'pupil',
#    'key',
#    'driver',
#    'Paula',
#    'shark'],
#   'cake': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'captain',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'bat',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'brain',
#    'monster',
#    'coach',
#    'flag',
#    'muffin',
#    'lion',
#    'scientist',
#    'balloon',
#    'donkey',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'fig',
#    'jacket',
#    'pancake',
#    'spokesman',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'friend',
#    'watch',
#    'biscuit',
#    'wolf',
#    'potato',
#    'leaf',
#    'prisoner',
#    'bird',
#    'hat',
#    'pumpkin',
#    'shell',
#    'plant',
#    'banana',
#    'nail',
#    'hammer',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'customer',
#    'politician',
#    'wine',
#    'hamburger',
#    'chicken',
#    'knife',
#    'researcher',
#    'crown',
#    'doll',
#    'champion',
#    'cow',
#    'journalist',
#    'liver',
#    'professor',
#    'jigsaw',
#    'hen',
#    'soap',
#    'flower',
#    'block',
#    'prince',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'guy',
#    'director',
#    'chemical',
#    'yogurt',
#    'dealer',
#    'brick',
#    'shirt',
#    'bunny',
#    'student',
#    'duke',
#    'needle',
#    'moose',
#    'kitty',
#    'princess',
#    'can',
#    'seed',
#    'guitar',
#    'toy',
#    'clock',
#    'pickle',
#    'hero',
#    'resident',
#    'mother',
#    'purse',
#    'radio',
#    'fly',
#    'crystal',
#    'bear',
#    'manager',
#    'basket',
#    'passenger',
#    'plate',
#    'duck',
#    'penguin',
#    'patient',
#    'farmer',
#    'puppy',
#    'queen',
#    'pillow',
#    'writer',
#    'father',
#    'mirror',
#    'host',
#    'gumball',
#    'jar',
#    'pony',
#    'tiger',
#    'producer',
#    'consumer',
#    'fish',
#    'soldier',
#    'towel',
#    'newspaper',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'pizza',
#    'toothbrush',
#    'king',
#    'cloud',
#    'weapon',
#    'creature',
#    'button',
#    'bag',
#    'buyer',
#    'bean',
#    'molecule',
#    'brush',
#    'tenant',
#    'bell',
#    'pupil',
#    'key',
#    'driver'],
#   'forwarded': ['passed',
#    'sold',
#    'lended',
#    'fed',
#    'offered',
#    'slipped',
#    'awarded',
#    'posted',
#    'handed',
#    'rented',
#    'mailed',
#    'brought',
#    'wired',
#    'returned',
#    'promised',
#    'sent',
#    'served',
#    'loaned'],
#   'Levi': ['Emma',
#    'Evelyn',
#    'Charlotte',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'Oliver',
#    'Mia',
#    'Sophia',
#    'David',
#    'James',
#    'Michael',
#    'Chloe',
#    'Dylan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'Alexander',
#    'Noah',
#    'Asher',
#    'Natalie',
#    'Thomas',
#    'William',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Wyatt',
#    'Abigail',
#    'Leo',
#    'Jacob',
#    'Aria',
#    'Joshua',
#    'John',
#    'Savannah',
#    'Caleb',
#    'Luke',
#    'Henry',
#    'Owen',
#    'Samuel',
#    'Julian',
#    'Aurora',
#    'Madison',
#    'Mason',
#    'Emily',
#    'Jayden',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Zoe',
#    'Leah',
#    'Grace',
#    'Joseph',
#    'Riley',
#    'Stella',
#    'Violet',
#    'Theodore',
#    'Carter',
#    'Hannah',
#    'Audrey',
#    'Anthony',
#    'Claire'],
#   'Charlotte': ['rose',
#    'Emma',
#    'teacher',
#    'Evelyn',
#    'girl',
#    'Levi',
#    'cookie',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'box',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'pen',
#    'Oliver',
#    'bottle',
#    'priest',
#    'lawyer',
#    'Mia',
#    'Sophia',
#    'David',
#    'Camila',
#    'James',
#    'game',
#    'chalk',
#    'Michael',
#    'chair',
#    'Chloe',
#    'bee',
#    'brain',
#    'Dylan',
#    'flag',
#    'Ethan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'scientist',
#    'Alexander',
#    'Aubrey',
#    'Hazel',
#    'Noah',
#    'ball',
#    'Harper',
#    'Asher',
#    'Natalie',
#    'Luna',
#    'Thomas',
#    'Avery',
#    'prisoner',
#    'bird',
#    'William',
#    'plant',
#    'Addison',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Lincoln',
#    'Lucas',
#    'Wyatt',
#    'bowl',
#    'spoon',
#    'Layla',
#    'Abigail',
#    'Leo',
#    'Jacob',
#    'knife',
#    'Aria',
#    'Joshua',
#    'John',
#    'liver',
#    'Savannah',
#    'Caleb',
#    'professor',
#    'human',
#    'Nathan',
#    'Luke',
#    'flower',
#    'Henry',
#    'Jack',
#    'split',
#    'Ellie',
#    'Owen',
#    'Samuel',
#    'bucket',
#    'Julian',
#    'Skylar',
#    'director',
#    'Aurora',
#    'brick',
#    'Madison',
#    'student',
#    'Mateo',
#    'moose',
#    'Mason',
#    'Emily',
#    'clock',
#    'Jayden',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Bella',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Zoe',
#    'Leah',
#    'Grace',
#    'queen',
#    'Andrew',
#    'Joseph',
#    'gumball',
#    'tiger',
#    'poet',
#    'Grayson',
#    'Penelope',
#    'Isaac',
#    'Riley',
#    'Brooklyn',
#    'Ryan',
#    'governor',
#    'Stella',
#    'toothbrush',
#    'Violet',
#    'button',
#    'Theodore',
#    'Lillian',
#    'Carter',
#    'Nora',
#    'Hannah',
#    'Jaxon',
#    'Zoey',
#    'Christopher',
#    'Audrey',
#    'Anthony',
#    'Paula',
#    'Claire',
#    'shark'],
#   'captain': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'cookie',
#    'horse',
#    'mouse',
#    'cat',
#    'giraffe',
#    'box',
#    'butterfly',
#    'priest',
#    'drink',
#    'child',
#    'crayon',
#    'frog',
#    'sandwich',
#    'visitor',
#    'monkey',
#    'baby',
#    'raisin',
#    'monster',
#    'coach',
#    'lion',
#    'scientist',
#    'donkey',
#    'landlord',
#    'pancake',
#    'pig',
#    'bird',
#    'customer',
#    'politician',
#    'hamburger',
#    'chicken',
#    'turkey',
#    'cow',
#    'journalist',
#    'professor',
#    'jigsaw',
#    'hen',
#    'block',
#    'prince',
#    'zebra',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'lamb',
#    'bunny',
#    'duke',
#    'kitty',
#    'princess',
#    'tourist',
#    'toy',
#    'hero',
#    'mother',
#    'purse',
#    'fly',
#    'bear',
#    'manager',
#    'plate',
#    'duck',
#    'penguin',
#    'patient',
#    'puppy',
#    'writer',
#    'father',
#    'tiger',
#    'president',
#    'poet',
#    'producer',
#    'chief',
#    'fish',
#    'soldier',
#    'guest',
#    'judge',
#    'governor',
#    'guard',
#    'weapon',
#    'creature',
#    'buyer',
#    'tenant',
#    'sheep',
#    'driver'],
#   'needed': ['liked',
#    'meant',
#    'hoped',
#    'preferred',
#    'expected',
#    'loved',
#    'dreamed',
#    'wanted',
#    'attempted',
#    'craved',
#    'wished',
#    'hated',
#    'planned',
#    'longed',
#    'intended',
#    'tried',
#    'itched',
#    'enjoyed',
#    'yearned'],
#   'cookie': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'Emma',
#    'teacher',
#    'girl',
#    'cake',
#    'Charlotte',
#    'captain',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'Scarlett',
#    'pencil',
#    'Liam',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'bat',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'Chloe',
#    'raisin',
#    'bee',
#    'brain',
#    'monster',
#    'flag',
#    'muffin',
#    'Ava',
#    'lion',
#    'scientist',
#    'balloon',
#    'cracker',
#    'cup',
#    'Alexander',
#    'sweetcorn',
#    'fig',
#    'Hazel',
#    'jacket',
#    'pancake',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'friend',
#    'watch',
#    'Natalie',
#    'biscuit',
#    'potato',
#    'leaf',
#    'prisoner',
#    'bird',
#    'hat',
#    'pumpkin',
#    'shell',
#    'plant',
#    'banana',
#    'nail',
#    'hammer',
#    'Sebastian',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'customer',
#    'Layla',
#    'wine',
#    'hamburger',
#    'chicken',
#    'knife',
#    'researcher',
#    'crown',
#    'turkey',
#    'doll',
#    'cow',
#    'journalist',
#    'liver',
#    'professor',
#    'human',
#    'jigsaw',
#    'soap',
#    'flower',
#    'block',
#    'split',
#    'prince',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'guy',
#    'director',
#    'chemical',
#    'yogurt',
#    'brick',
#    'shirt',
#    'bunny',
#    'Madison',
#    'student',
#    'duke',
#    'Mateo',
#    'needle',
#    'moose',
#    'can',
#    'seed',
#    'guitar',
#    'Emily',
#    'toy',
#    'clock',
#    'pickle',
#    'hero',
#    'purse',
#    'radio',
#    'fly',
#    'crystal',
#    'Mila',
#    'bear',
#    'basket',
#    'passenger',
#    'plate',
#    'duck',
#    'penguin',
#    'Zoe',
#    'patient',
#    'farmer',
#    'queen',
#    'pillow',
#    'father',
#    'mirror',
#    'host',
#    'gumball',
#    'jar',
#    'pony',
#    'tiger',
#    'poet',
#    'producer',
#    'chief',
#    'consumer',
#    'fish',
#    'soldier',
#    'towel',
#    'newspaper',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'pizza',
#    'governor',
#    'toothbrush',
#    'Violet',
#    'cloud',
#    'weapon',
#    'button',
#    'Carter',
#    'bag',
#    'buyer',
#    'bean',
#    'molecule',
#    'Jaxon',
#    'Zoey',
#    'brush',
#    'tenant',
#    'bell',
#    'key',
#    'driver',
#    'Paula',
#    'shark'],
#   'passed': ['forwarded',
#    'sold',
#    'lended',
#    'fed',
#    'offered',
#    'slipped',
#    'awarded',
#    'posted',
#    'handed',
#    'rented',
#    'mailed',
#    'brought',
#    'wired',
#    'returned',
#    'promised',
#    'sent',
#    'served',
#    'loaned'],
#   'ring': ['rose',
#    'dog',
#    'boy',
#    'girl',
#    'cake',
#    'cookie',
#    'horse',
#    'strawberry',
#    'cat',
#    'book',
#    'donut',
#    'box',
#    'pencil',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'bat',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'sandwich',
#    'turtle',
#    'game',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'flag',
#    'muffin',
#    'lion',
#    'balloon',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'jacket',
#    'pancake',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'watch',
#    'biscuit',
#    'potato',
#    'leaf',
#    'bird',
#    'hat',
#    'pumpkin',
#    'plant',
#    'banana',
#    'nail',
#    'hammer',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'wine',
#    'hamburger',
#    'knife',
#    'crown',
#    'doll',
#    'liver',
#    'professor',
#    'jigsaw',
#    'soap',
#    'flower',
#    'block',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'chemical',
#    'yogurt',
#    'brick',
#    'shirt',
#    'needle',
#    'can',
#    'seed',
#    'guitar',
#    'toy',
#    'clock',
#    'pickle',
#    'radio',
#    'fly',
#    'crystal',
#    'bear',
#    'basket',
#    'plate',
#    'pillow',
#    'father',
#    'mirror',
#    'gumball',
#    'jar',
#    'pony',
#    'towel',
#    'newspaper',
#    'fruit',
#    'beer',
#    'shoe',
#    'pizza',
#    'toothbrush',
#    'cloud',
#    'weapon',
#    'button',
#    'bag',
#    'bean',
#    'molecule',
#    'brush',
#    'bell',
#    'key'],
#   'beside': ['on'],
#   'bed': ['table', 'stage', 'stool'],
#   'horse': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'captain',
#    'cookie',
#    'ring',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'bat',
#    'squirrel',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'monster',
#    'coach',
#    'flag',
#    'lion',
#    'scientist',
#    'balloon',
#    'donkey',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'jacket',
#    'landlord',
#    'pancake',
#    'spokesman',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'watch',
#    'wolf',
#    'potato',
#    'leaf',
#    'prisoner',
#    'bird',
#    'hat',
#    'pumpkin',
#    'bowl',
#    'mandarin',
#    'customer',
#    'wine',
#    'hamburger',
#    'chicken',
#    'researcher',
#    'turkey',
#    'champion',
#    'cow',
#    'professor',
#    'hen',
#    'soap',
#    'flower',
#    'block',
#    'prince',
#    'doctor',
#    'zebra',
#    'bucket',
#    'lollipop',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'chemical',
#    'lamb',
#    'bunny',
#    'student',
#    'duke',
#    'moose',
#    'kitty',
#    'princess',
#    'seed',
#    'guitar',
#    'tourist',
#    'clock',
#    'pickle',
#    'hero',
#    'mother',
#    'fly',
#    'crystal',
#    'bear',
#    'manager',
#    'basket',
#    'passenger',
#    'plate',
#    'duck',
#    'penguin',
#    'patient',
#    'farmer',
#    'queen',
#    'pillow',
#    'writer',
#    'father',
#    'jar',
#    'pony',
#    'tiger',
#    'president',
#    'poet',
#    'producer',
#    'chief',
#    'consumer',
#    'fish',
#    'soldier',
#    'towel',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'judge',
#    'pizza',
#    'governor',
#    'cloud',
#    'creature',
#    'kid',
#    'buyer',
#    'molecule',
#    'brush',
#    'tenant',
#    'sheep',
#    'pupil',
#    'key',
#    'driver'],
#   'table': ['bed',
#    'book',
#    'box',
#    'bottle',
#    'stage',
#    'house',
#    'basket',
#    'car',
#    'glass',
#    'coffin',
#    'rock'],
#   'mouse': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'captain',
#    'cookie',
#    'horse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'squirrel',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'monster',
#    'coach',
#    'flag',
#    'muffin',
#    'lion',
#    'scientist',
#    'balloon',
#    'donkey',
#    'cup',
#    'sweetcorn',
#    'fig',
#    'landlord',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'watch',
#    'biscuit',
#    'wolf',
#    'leaf',
#    'prisoner',
#    'bird',
#    'pumpkin',
#    'banana',
#    'hammer',
#    'bowl',
#    'mandarin',
#    'customer',
#    'politician',
#    'wine',
#    'hamburger',
#    'chicken',
#    'researcher',
#    'turkey',
#    'doll',
#    'champion',
#    'cow',
#    'journalist',
#    'professor',
#    'jigsaw',
#    'hen',
#    'flower',
#    'block',
#    'prince',
#    'doctor',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'chemical',
#    'yogurt',
#    'dealer',
#    'lamb',
#    'bunny',
#    'student',
#    'duke',
#    'needle',
#    'moose',
#    'kitty',
#    'princess',
#    'guitar',
#    'toy',
#    'clock',
#    'pickle',
#    'mother',
#    'radio',
#    'fly',
#    'bear',
#    'manager',
#    'basket',
#    'servant',
#    'passenger',
#    'duck',
#    'penguin',
#    'patient',
#    'farmer',
#    'puppy',
#    'queen',
#    'pillow',
#    'writer',
#    'father',
#    'host',
#    'gumball',
#    'jar',
#    'pony',
#    'tiger',
#    'president',
#    'poet',
#    'producer',
#    'chief',
#    'consumer',
#    'fish',
#    'soldier',
#    'newspaper',
#    'fruit',
#    'guest',
#    'shoe',
#    'judge',
#    'pizza',
#    'governor',
#    'guard',
#    'king',
#    'creature',
#    'kid',
#    'buyer',
#    'molecule',
#    'brush',
#    'tenant',
#    'sheep',
#    'pupil',
#    'key',
#    'driver'],
#   'Amelia': ['Emma',
#    'Evelyn',
#    'Levi',
#    'Charlotte',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'Oliver',
#    'Mia',
#    'Sophia',
#    'David',
#    'Camila',
#    'James',
#    'Michael',
#    'Chloe',
#    'Dylan',
#    'Ethan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'Alexander',
#    'Aubrey',
#    'Hazel',
#    'Noah',
#    'Harper',
#    'Asher',
#    'Natalie',
#    'Luna',
#    'Thomas',
#    'Avery',
#    'William',
#    'Addison',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Lucas',
#    'Wyatt',
#    'Layla',
#    'Abigail',
#    'Leo',
#    'Jacob',
#    'Aria',
#    'Joshua',
#    'John',
#    'Savannah',
#    'Caleb',
#    'Nathan',
#    'Luke',
#    'Henry',
#    'Jack',
#    'Ellie',
#    'Owen',
#    'Samuel',
#    'Julian',
#    'Skylar',
#    'Aurora',
#    'Madison',
#    'Mateo',
#    'Mason',
#    'Emily',
#    'Jayden',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Bella',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Zoe',
#    'Leah',
#    'Grace',
#    'Andrew',
#    'Joseph',
#    'Grayson',
#    'Penelope',
#    'Isaac',
#    'Riley',
#    'Stella',
#    'Violet',
#    'Theodore',
#    'Lillian',
#    'Carter',
#    'Nora',
#    'Hannah',
#    'Zoey',
#    'Christopher',
#    'Audrey',
#    'Anthony',
#    'Claire'],
#   'strawberry': ['rose',
#    'dog',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'lawyer',
#    'bat',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'brain',
#    'monster',
#    'flag',
#    'muffin',
#    'lion',
#    'scientist',
#    'balloon',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'fig',
#    'jacket',
#    'pancake',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'watch',
#    'biscuit',
#    'wolf',
#    'potato',
#    'leaf',
#    'prisoner',
#    'hat',
#    'pumpkin',
#    'shell',
#    'plant',
#    'banana',
#    'nail',
#    'hammer',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'wine',
#    'hamburger',
#    'chicken',
#    'knife',
#    'researcher',
#    'crown',
#    'doll',
#    'journalist',
#    'liver',
#    'professor',
#    'jigsaw',
#    'hen',
#    'soap',
#    'flower',
#    'block',
#    'prince',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'guy',
#    'chemical',
#    'yogurt',
#    'brick',
#    'shirt',
#    'bunny',
#    'student',
#    'needle',
#    'princess',
#    'can',
#    'seed',
#    'guitar',
#    'toy',
#    'clock',
#    'pickle',
#    'purse',
#    'radio',
#    'fly',
#    'crystal',
#    'bear',
#    'manager',
#    'basket',
#    'passenger',
#    'plate',
#    'duck',
#    'penguin',
#    'farmer',
#    'pillow',
#    'father',
#    'mirror',
#    'gumball',
#    'jar',
#    'pony',
#    'consumer',
#    'fish',
#    'towel',
#    'newspaper',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'pizza',
#    'toothbrush',
#    'king',
#    'cloud',
#    'weapon',
#    'creature',
#    'button',
#    'bag',
#    'bean',
#    'molecule',
#    'brush',
#    'bell',
#    'key'],
#   'cat': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'captain',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'priest',
#    'lawyer',
#    'bat',
#    'squirrel',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'citizen',
#    'sandwich',
#    'visitor',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'brain',
# ...
#    'split',
#    'Samuel',
#    'bucket',
#    'Julian',
#    'director',
#    'brick',
#    'Madison',
#    'student',
#    'Mateo',
#    'moose',
#    'Mason',
#    'Emily',
#    'clock',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Bella',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Zoe',
#    'queen',
#    'Andrew',
#    'Joseph',
#    'gumball',
#    'tiger',
#    'poet',
#    'Grayson',
#    'Brooklyn',
#    'governor',
#    'Stella',
#    'toothbrush',
#    'Violet',
#    'button',
#    'Theodore',
#    'Lillian',
#    'Carter',
#    'Nora',
#    'Hannah',
#    'Zoey',
#    'Anthony',
#    'Paula',
#    'shark'],
#   'Zoey': ['rose',
#    'Emma',
#    'teacher',
#    'Evelyn',
#    'girl',
#    'Charlotte',
#    'cookie',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'box',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'pen',
#    'Oliver',
#    'bottle',
#    'priest',
#    'lawyer',
#    'Mia',
#    'Sophia',
#    'David',
#    'Camila',
#    'James',
#    'game',
#    'chalk',
#    'Michael',
#    'chair',
#    'Chloe',
#    'bee',
#    'brain',
#    'Dylan',
#    'flag',
#    'Ethan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'scientist',
#    'Alexander',
#    'Hazel',
#    'Noah',
#    'ball',
#    'Harper',
#    'Asher',
#    'Natalie',
#    'Luna',
#    'Thomas',
#    'Avery',
#    'prisoner',
#    'bird',
#    'William',
#    'plant',
#    'Addison',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Lucas',
#    'bowl',
#    'spoon',
#    'Layla',
#    'Abigail',
#    'Jacob',
#    'knife',
#    'Aria',
#    'Joshua',
#    'John',
#    'liver',
#    'professor',
#    'human',
#    'Nathan',
#    'Luke',
#    'flower',
#    'Jack',
#    'split',
#    'Ellie',
#    'Owen',
#    'Samuel',
#    'bucket',
#    'Julian',
#    'Skylar',
#    'director',
#    'brick',
#    'Madison',
#    'student',
#    'Mateo',
#    'moose',
#    'Mason',
#    'Emily',
#    'clock',
#    'Sofia',
#    'Lily',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Zoe',
#    'Leah',
#    'Grace',
#    'queen',
#    'Andrew',
#    'Joseph',
#    'gumball',
#    'tiger',
#    'poet',
#    'Penelope',
#    'Isaac',
#    'Riley',
#    'governor',
#    'Stella',
#    'toothbrush',
#    'Violet',
#    'button',
#    'Theodore',
#    'Lillian',
#    'Carter',
#    'Hannah',
#    'Jaxon',
#    'Christopher',
#    'Anthony',
#    'Paula',
#    'Claire',
#    'shark'],
#   'brush': ['rose',
#    'dog',
#    'boy',
#    'girl',
#    'cake',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'pen',
#    'melon',
#    'bottle',
#    'priest',
#    'bat',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'sandwich',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'flag',
#    'muffin',
#    'balloon',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'jacket',
#    'pancake',
#    'pretzel',
#    'glue',
#    'ball',
#    'watch',
#    'biscuit',
#    'potato',
#    'leaf',
#    'hat',
#    'pumpkin',
#    'shell',
#    'plant',
#    'banana',
#    'nail',
#    'hammer',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'wine',
#    'hamburger',
#    'knife',
#    'crown',
#    'doll',
#    'champion',
#    'jigsaw',
#    'soap',
#    'flower',
#    'block',
#    'prince',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'chemical',
#    'yogurt',
#    'brick',
#    'shirt',
#    'bunny',
#    'needle',
#    'can',
#    'seed',
#    'guitar',
#    'toy',
#    'clock',
#    'pickle',
#    'purse',
#    'radio',
#    'bear',
#    'basket',
#    'passenger',
#    'plate',
#    'pillow',
#    'mirror',
#    'gumball',
#    'jar',
#    'consumer',
#    'fish',
#    'towel',
#    'newspaper',
#    'fruit',
#    'beer',
#    'shoe',
#    'pizza',
#    'toothbrush',
#    'cloud',
#    'weapon',
#    'button',
#    'bag',
#    'bean',
#    'molecule',
#    'bell',
#    'key'],
#   'tenant': ['dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'captain',
#    'cookie',
#    'horse',
#    'mouse',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'butterfly',
#    'priest',
#    'drink',
#    'child',
#    'frog',
#    'citizen',
#    'visitor',
#    'monkey',
#    'baby',
#    'raisin',
#    'monster',
#    'coach',
#    'lion',
#    'scientist',
#    'balloon',
#    'donkey',
#    'landlord',
#    'friend',
#    'leaf',
#    'bird',
#    'banana',
#    'customer',
#    'hamburger',
#    'chicken',
#    'cow',
#    'professor',
#    'block',
#    'zebra',
#    'goose',
#    'guy',
#    'crocodile',
#    'director',
#    'lamb',
#    'student',
#    'duke',
#    'kitty',
#    'princess',
#    'tourist',
#    'mother',
#    'fly',
#    'bear',
#    'duck',
#    'penguin',
#    'writer',
#    'father',
#    'pony',
#    'tiger',
#    'president',
#    'poet',
#    'chief',
#    'fish',
#    'soldier',
#    'guest',
#    'shoe',
#    'judge',
#    'governor',
#    'king',
#    'kid',
#    'sheep',
#    'driver'],
#   'sheep': ['dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'captain',
#    'horse',
#    'mouse',
#    'cat',
#    'giraffe',
#    'butterfly',
#    'priest',
#    'lawyer',
#    'child',
#    'frog',
#    'citizen',
#    'monkey',
#    'baby',
#    'monster',
#    'coach',
#    'lion',
#    'donkey',
#    'spokesman',
#    'pig',
#    'bird',
#    'customer',
#    'politician',
#    'chicken',
#    'turkey',
#    'cow',
#    'professor',
#    'hen',
#    'prince',
#    'zebra',
#    'goose',
#    'crocodile',
#    'lamb',
#    'bunny',
#    'student',
#    'duke',
#    'moose',
#    'kitty',
#    'princess',
#    'tourist',
#    'mother',
#    'fly',
#    'bear',
#    'manager',
#    'patient',
#    'writer',
#    'father',
#    'host',
#    'pony',
#    'tiger',
#    'poet',
#    'chief',
#    'fish',
#    'soldier',
#    'guest',
#    'governor',
#    'guard',
#    'king',
#    'buyer',
#    'tenant',
#    'driver'],
#   'bell': ['rose',
#    'girl',
#    'cake',
#    'cookie',
#    'ring',
#    'strawberry',
#    'cat',
#    'book',
#    'donut',
#    'box',
#    'pencil',
#    'pen',
#    'melon',
#    'bottle',
#    'bat',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'sandwich',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'chair',
#    'raisin',
#    'brain',
#    'monster',
#    'flag',
#    'muffin',
#    'lion',
#    'balloon',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'fig',
#    'jacket',
#    'pancake',
#    'pretzel',
#    'glue',
#    'ball',
#    'watch',
#    'biscuit',
#    'potato',
#    'leaf',
#    'hat',
#    'pumpkin',
#    'shell',
#    'plant',
#    'banana',
#    'nail',
#    'hammer',
#    'tool',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'customer',
#    'wine',
#    'hamburger',
#    'knife',
#    'crown',
#    'doll',
#    'liver',
#    'jigsaw',
#    'flower',
#    'block',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'yogurt',
#    'brick',
#    'shirt',
#    'needle',
#    'can',
#    'seed',
#    'guitar',
#    'toy',
#    'clock',
#    'pickle',
#    'purse',
#    'radio',
#    'crystal',
#    'bear',
#    'basket',
#    'plate',
#    'pillow',
#    'mirror',
#    'gumball',
#    'jar',
#    'towel',
#    'newspaper',
#    'fruit',
#    'beer',
#    'shoe',
#    'pizza',
#    'toothbrush',
#    'cloud',
#    'weapon',
#    'button',
#    'bean',
#    'brush',
#    'pupil'],
#   'Christopher': ['Emma',
#    'Charlotte',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'Oliver',
#    'Mia',
#    'Sophia',
#    'James',
#    'Michael',
#    'Chloe',
#    'Ethan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'Alexander',
#    'Hazel',
#    'Noah',
#    'Harper',
#    'Asher',
#    'Luna',
#    'Thomas',
#    'Avery',
#    'William',
#    'Addison',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Lucas',
#    'Wyatt',
#    'Layla',
#    'Abigail',
#    'Jacob',
#    'Aria',
#    'Joshua',
#    'Nathan',
#    'Luke',
#    'Ellie',
#    'Owen',
#    'Skylar',
#    'Aurora',
#    'Madison',
#    'Mateo',
#    'Mason',
#    'Emily',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Bella',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Leah',
#    'Grace',
#    'Andrew',
#    'Joseph',
#    'Penelope',
#    'Isaac',
#    'Riley',
#    'Brooklyn',
#    'Stella',
#    'Violet',
#    'Theodore',
#    'Lillian',
#    'Carter',
#    'Zoey',
#    'Audrey',
#    'Anthony'],
#   'pupil': ['dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'horse',
#    'mouse',
#    'cat',
#    'giraffe',
#    'donut',
#    'box',
#    'butterfly',
#    'lawyer',
#    'child',
#    'frog',
#    'turtle',
#    'monkey',
#    'baby',
#    'bee',
#    'monster',
#    'coach',
#    'lion',
#    'scientist',
#    'spokesman',
#    'pig',
#    'friend',
#    'prisoner',
#    'bird',
#    'customer',
#    'chicken',
#    'champion',
#    'journalist',
#    'professor',
#    'hen',
#    'block',
#    'prince',
#    'doctor',
#    'zebra',
#    'guy',
#    'crocodile',
#    'dealer',
#    'brick',
#    'bunny',
#    'student',
#    'moose',
#    'kitty',
#    'princess',
#    'fly',
#    'bear',
#    'duck',
#    'farmer',
#    'puppy',
#    'queen',
#    'host',
#    'tiger',
#    'producer',
#    'chief',
#    'soldier',
#    'judge',
#    'pizza',
#    'king',
#    'creature',
#    'bell'],
#   'key': ['rose',
#    'dog',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'cookie',
#    'ring',
#    'horse',
#    'mouse',
#    'strawberry',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'pencil',
#    'deer',
#    'pen',
#    'butterfly',
#    'melon',
#    'bottle',
#    'bat',
#    'drink',
#    'child',
#    'penny',
#    'crayon',
#    'frog',
#    'sandwich',
#    'turtle',
#    'game',
#    'monkey',
#    'chalk',
#    'present',
#    'baby',
#    'chair',
#    'raisin',
#    'bee',
#    'brain',
#    'monster',
#    'flag',
#    'muffin',
#    'lion',
#    'balloon',
#    'cracker',
#    'cup',
#    'sweetcorn',
#    'fig',
#    'jacket',
#    'pancake',
#    'pretzel',
#    'pig',
#    'glue',
#    'ball',
#    'watch',
#    'biscuit',
#    'wolf',
#    'potato',
#    'prisoner',
#    'hat',
#    'pumpkin',
#    'banana',
#    'nail',
#    'hammer',
#    'tool',
#    'coin',
#    'bowl',
#    'mandarin',
#    'spoon',
#    'wine',
#    'hamburger',
#    'chicken',
#    'knife',
#    'crown',
#    'doll',
#    'journalist',
#    'professor',
#    'jigsaw',
#    'hen',
#    'flower',
#    'block',
#    'zebra',
#    'bucket',
#    'scarf',
#    'lollipop',
#    'chemical',
#    'yogurt',
#    'brick',
#    'princess',
#    'can',
#    'seed',
#    'guitar',
#    'toy',
#    'clock',
#    'pickle',
#    'purse',
#    'radio',
#    'fly',
#    'bear',
#    'manager',
#    'basket',
#    'plate',
#    'farmer',
#    'pillow',
#    'father',
#    'mirror',
#    'gumball',
#    'jar',
#    'pony',
#    'fish',
#    'towel',
#    'newspaper',
#    'fruit',
#    'guest',
#    'beer',
#    'shoe',
#    'pizza',
#    'toothbrush',
#    'king',
#    'cloud',
#    'weapon',
#    'creature',
#    'bean',
#    'brush'],
#   'coffin': ['table'],
#   'Audrey': ['Emma',
#    'Evelyn',
#    'Levi',
#    'Charlotte',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'Oliver',
#    'Mia',
#    'Sophia',
#    'David',
#    'James',
#    'Michael',
#    'Chloe',
#    'Dylan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'Alexander',
#    'Noah',
#    'Luna',
#    'Thomas',
#    'William',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Lincoln',
#    'Wyatt',
#    'Layla',
#    'Abigail',
#    'Leo',
#    'Jacob',
#    'Aria',
#    'Savannah',
#    'Caleb',
#    'Luke',
#    'Henry',
#    'Jack',
#    'Ellie',
#    'Owen',
#    'Samuel',
#    'Julian',
#    'Skylar',
#    'Aurora',
#    'Madison',
#    'Mason',
#    'Emily',
#    'Jayden',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Leah',
#    'Joseph',
#    'Isaac',
#    'Riley',
#    'Ryan',
#    'Stella',
#    'Violet',
#    'Theodore',
#    'Carter',
#    'Nora',
#    'Hannah',
#    'Christopher',
#    'Anthony',
#    'Claire'],
#   'frowned': ['rolled',
#    'disintegrated',
#    'studied',
#    'crumpled',
#    'nursed',
#    'painted',
#    'slid',
#    'laughed',
#    'changed',
#    'inflated',
#    'decomposed',
#    'smiled',
#    'floated',
#    'cried',
#    'doubled',
#    'improved',
#    'shortened',
#    'noticed',
#    'burned',
#    'heard',
#    'snapped',
#    'packed',
#    'enlarged',
#    'collapsed',
#    'snored',
#    'split',
#    'examined',
#    'reddened',
#    'juggled',
#    'screamed',
#    'gasped',
#    'scoffed',
#    'stuttered',
#    'observed',
#    'snoozed'],
#   'rock': ['table'],
#   'snoozed': ['rolled',
#    'disintegrated',
#    'studied',
#    'crumpled',
#    'nursed',
#    'painted',
#    'slid',
#    'laughed',
#    'changed',
#    'inflated',
#    'decomposed',
#    'smiled',
#    'floated',
#    'cried',
#    'doubled',
#    'improved',
#    'shortened',
#    'noticed',
#    'burned',
#    'heard',
#    'snapped',
#    'packed',
#    'enlarged',
#    'collapsed',
#    'snored',
#    'split',
#    'examined',
#    'reddened',
#    'juggled',
#    'screamed',
#    'gasped',
#    'scoffed',
#    'stuttered',
#    'observed',
#    'frowned'],
#   'yearned': ['needed',
#    'liked',
#    'meant',
#    'hoped',
#    'preferred',
#    'expected',
#    'loved',
#    'dreamed',
#    'wanted',
#    'attempted',
#    'craved',
#    'wished',
#    'hated',
#    'planned',
#    'longed',
#    'intended',
#    'tried',
#    'enjoyed'],
#   'driver': ['rose',
#    'dog',
#    'sailor',
#    'boy',
#    'teacher',
#    'girl',
#    'cake',
#    'captain',
#    'cookie',
#    'horse',
#    'mouse',
#    'cat',
#    'book',
#    'giraffe',
#    'donut',
#    'box',
#    'butterfly',
#    'melon',
#    'priest',
#    'lawyer',
#    'child',
#    'frog',
#    'citizen',
#    'sandwich',
#    'game',
#    'monkey',
#    'baby',
#    'monster',
#    'coach',
#    'lion',
#    'scientist',
#    'donkey',
#    'pig',
#    'bird',
#    'mandarin',
#    'customer',
#    'chicken',
#    'champion',
#    'cow',
#    'professor',
#    'hen',
#    'block',
#    'prince',
#    'zebra',
#    'goose',
#    'dealer',
#    'lamb',
#    'bunny',
#    'student',
#    'moose',
#    'kitty',
#    'princess',
#    'tourist',
#    'mother',
#    'fly',
#    'bear',
#    'manager',
#    'servant',
#    'penguin',
#    'patient',
#    'queen',
#    'pillow',
#    'writer',
#    'father',
#    'pony',
#    'tiger',
#    'poet',
#    'chief',
#    'fish',
#    'soldier',
#    'guest',
#    'judge',
#    'governor',
#    'guard',
#    'king',
#    'tenant',
#    'sheep'],
#   'Anthony': ['Emma',
#    'Levi',
#    'Charlotte',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'Liam',
#    'Olivia',
#    'Oliver',
#    'Mia',
#    'Sophia',
#    'Camila',
#    'James',
#    'Michael',
#    'Chloe',
#    'Dylan',
#    'Ethan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'Alexander',
#    'Hazel',
#    'Noah',
#    'Harper',
#    'Asher',
#    'Luna',
#    'Avery',
#    'William',
#    'Addison',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Lincoln',
#    'Lucas',
#    'Layla',
#    'Abigail',
#    'Jacob',
#    'Aria',
#    'Joshua',
#    'Nathan',
#    'Luke',
#    'Ellie',
#    'Owen',
#    'Skylar',
#    'Madison',
#    'Mateo',
#    'Mason',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Elijah',
#    'Zoe',
#    'Leah',
#    'Grace',
#    'Andrew',
#    'Joseph',
#    'Grayson',
#    'Isaac',
#    'Riley',
#    'Brooklyn',
#    'Stella',
#    'Violet',
#    'Theodore',
#    'Lillian',
#    'Carter',
#    'Jaxon',
#    'Zoey',
#    'Christopher',
#    'Audrey'],
#   'Paula': ['rose',
#    'Emma',
#    'teacher',
#    'girl',
#    'Charlotte',
#    'cookie',
#    'box',
#    'Scarlett',
#    'Liam',
#    'pen',
#    'bottle',
#    'priest',
#    'lawyer',
#    'game',
#    'chalk',
#    'chair',
#    'Chloe',
#    'bee',
#    'brain',
#    'flag',
#    'Ava',
#    'scientist',
#    'Alexander',
#    'Hazel',
#    'ball',
#    'Natalie',
#    'prisoner',
#    'bird',
#    'plant',
#    'Sebastian',
#    'bowl',
#    'spoon',
#    'Layla',
#    'knife',
#    'liver',
#    'professor',
#    'human',
#    'flower',
#    'split',
#    'bucket',
#    'director',
#    'brick',
#    'Madison',
#    'student',
#    'Mateo',
#    'moose',
#    'Emily',
#    'clock',
#    'Mila',
#    'Zoe',
#    'queen',
#    'gumball',
#    'tiger',
#    'poet',
#    'governor',
#    'toothbrush',
#    'Violet',
#    'button',
#    'Carter',
#    'Jaxon',
#    'Zoey',
#    'shark'],
#   'couch': ['box'],
#   'Claire': ['Emma',
#    'Evelyn',
#    'Levi',
#    'Charlotte',
#    'Amelia',
#    'Eleanor',
#    'Benjamin',
#    'Isabella',
#    'Scarlett',
#    'Liam',
#    'Olivia',
#    'Oliver',
#    'Mia',
#    'Sophia',
#    'David',
#    'Camila',
#    'James',
#    'Michael',
#    'Chloe',
#    'Dylan',
#    'Ethan',
#    'Matthew',
#    'Elizabeth',
#    'Ella',
#    'Ava',
#    'Alexander',
#    'Noah',
#    'Harper',
#    'Asher',
#    'Luna',
#    'Thomas',
#    'William',
#    'Aiden',
#    'Logan',
#    'Sebastian',
#    'Wyatt',
#    'Abigail',
#    'Leo',
#    'Jacob',
#    'Aria',
#    'John',
#    'Savannah',
#    'Caleb',
#    'Luke',
#    'Henry',
#    'Owen',
#    'Samuel',
#    'Julian',
#    'Aurora',
#    'Madison',
#    'Mateo',
#    'Mason',
#    'Emily',
#    'Jayden',
#    'Jackson',
#    'Sofia',
#    'Lily',
#    'Victoria',
#    'Daniel',
#    'Mila',
#    'Leah',
#    'Joseph',
#    'Grayson',
#    'Riley',
#    'Stella',
#    'Violet',
#    'Theodore',
#    'Hannah',
#    'Zoey',
#    'Audrey'],
#   'baked': ['packed'],
#   'squeezed': ['helped',
#    'rolled',
#    'changed',
#    'held',
#    'burned',
#    'found',
#    'discovered',
#    'tossed',
#    'worshipped']}}
